# %%
import synapseclient
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as sm
import statsmodels.stats.multitest as smm
import IPython.display as display

import MicroArray
from synapseHelpers import query2df
from toppGenePost import ToppGeneEnrichement

EXPR_ID = 'syn1968267'
METH_ID = 'syn2233188'
MIRSEQ_ID = 'syn2233189'
METADATA_ID = 'syn2248030'
pd.set_option('max_columns', 200)
syn = synapseclient.login()
# Out:
# Welcome, Larsson Omberg!
# Welcome, Larsson Omberg!

# %% [markdown]
# ##Download and annotate data
# 1. Downloads expression data from Synapse
# 2. Gets annotations from metadata in Synapse
# 3. Explore correlation between metadata fields

# %% [markdown]
# Query synapse for metadata of the expression data and store in a pandas dataframe

# %%
QUERY = 'select * from entity where passqc=="PASS" and diffnameshort=="SC" and parentId=="%s"' %METADATA_ID
metadata = query2df(syn.query(QUERY))
metadata.index = metadata['decoratedName']
metadata = metadata.drop(['decoratedName', 'name','passqc', 'bamId', 'fastqId','approvedfordiff', 
                          'pub', 'projdiff', 'projdifforiginlab', 'predifferentiatedcellname', 
                          'project',], axis=1)

#Replace text 'None' with None
metadata.replace(u'None', np.nan, inplace=True)

#Simplify certain disease labels
metadata.diffnameshort[metadata.diffnameshort=='EB-LF']='EB'
metadata.diffnameshort[metadata.diffnameshort=='SC-LF']='SC'
metadata.diffnameshort[metadata.diffnameshort=='SC-hpx']='SC'
#Display a table of metadata
display.HTML(metadata.to_html())#[['inductiongenes', 'donorsex', 'diffnameshort', 'donorstage', 'linetype', 'origcell']].to_html())
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/common.py:361: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   mask = arr == x
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cnv</th>
#       <th>diffnameshort</th>
#       <th>disease</th>
#       <th>donorsex</th>
#       <th>donorstage</th>
#       <th>dysr</th>
#       <th>ethnic</th>
#       <th>index</th>
#       <th>inductiongenes</th>
#       <th>lane</th>
#       <th>linetype</th>
#       <th>numberofreads</th>
#       <th>origcell</th>
#       <th>origlab</th>
#       <th>othertx</th>
#       <th>ratio</th>
#       <th>run</th>
#       <th>uniquelyalignedreads</th>
#       <th>vector</th>
#     </tr>
#     <tr>
#       <th>decoratedName</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>H9.144.7.7</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  7</td>
#       <td>           NaN</td>
#       <td> 7</td>
#       <td> hESC</td>
#       <td> 23118896</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.97</td>
#       <td> 144</td>
#       <td> 0.7930</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.102.2.5</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  5</td>
#       <td>           NaN</td>
#       <td> 2</td>
#       <td> hESC</td>
#       <td> 13133957</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.98</td>
#       <td> 102</td>
#       <td> 0.8445</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.119.3.7</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  7</td>
#       <td>           NaN</td>
#       <td> 3</td>
#       <td> hESC</td>
#       <td> 20573989</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.74</td>
#       <td> 119</td>
#       <td> 0.8357</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>IPS18-4-1.102.2.2</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>    NaN</td>
#       <td>      NaN</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  2</td>
#       <td>          OSKM</td>
#       <td> 2</td>
#       <td> iPSC</td>
#       <td> 14066561</td>
#       <td>              CD34+</td>
#       <td>    Mayhew/Malik</td>
#       <td>   .</td>
#       <td> 0.95</td>
#       <td> 102</td>
#       <td> 0.8459</td>
#       <td>               lenti</td>
#     </tr>
#     <tr>
#       <th>IPS18-4-2.102.2.4</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>    NaN</td>
#       <td>      NaN</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  4</td>
#       <td>          OSKM</td>
#       <td> 2</td>
#       <td> iPSC</td>
#       <td> 10866320</td>
#       <td>              CD34+</td>
#       <td>    Mayhew/Malik</td>
#       <td>   .</td>
#       <td> 0.97</td>
#       <td> 102</td>
#       <td> 0.8409</td>
#       <td>               lenti</td>
#     </tr>
#     <tr>
#       <th>SC11-004A.133.1.7</th>
#       <td> low level mosaic monosomy for Xp22.33-Xq28; in...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>      ped</td>
#       <td>                          normal</td>
#       <td>  Caucasian</td>
#       <td>  7</td>
#       <td>          OSKM</td>
#       <td> 1</td>
#       <td> iPSC</td>
#       <td> 17485226</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.89</td>
#       <td> 133</td>
#       <td> 0.8094</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>H9.102.2.6</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  6</td>
#       <td>           NaN</td>
#       <td> 2</td>
#       <td> hESC</td>
#       <td> 14141247</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.95</td>
#       <td> 102</td>
#       <td> 0.8425</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.119.5.3</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  3</td>
#       <td>           NaN</td>
#       <td> 5</td>
#       <td> hESC</td>
#       <td> 12741696</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.77</td>
#       <td> 119</td>
#       <td> 0.8502</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>SC11-004B.133.1.12</th>
#       <td> low level mosaic monosomy for Xp22.33-Xq28; in...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>      ped</td>
#       <td>                          normal</td>
#       <td>  Caucasian</td>
#       <td> 12</td>
#       <td>          OSKM</td>
#       <td> 1</td>
#       <td> iPSC</td>
#       <td> 17173640</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.90</td>
#       <td> 133</td>
#       <td> 0.8096</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>SC11-003B.133.1.6</th>
#       <td> &lt;10% cells have mosaic monosomy at Xp22.33-Xq2...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>      ped</td>
#       <td> Trisomy 12, del8p23 in 17 of 20</td>
#       <td>  Caucasian</td>
#       <td>  6</td>
#       <td>          OSKM</td>
#       <td> 1</td>
#       <td> iPSC</td>
#       <td> 17672712</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.90</td>
#       <td> 133</td>
#       <td> 0.8070</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>SC11-007A.119.3.5</th>
#       <td>                    1.69 Mb bp duplication at 6q21</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>   male</td>
#       <td>      ped</td>
#       <td>                          normal</td>
#       <td> HispLatino</td>
#       <td>  5</td>
#       <td>          OSKM</td>
#       <td> 3</td>
#       <td> iPSC</td>
#       <td> 13217328</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.75</td>
#       <td> 119</td>
#       <td> 0.8346</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>SC11-006A.119.1.4</th>
#       <td>            2.15 Mb Mosaic Duplication at 20q11.21</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>   male</td>
#       <td>      ped</td>
#       <td>                          normal</td>
#       <td> HispLatino</td>
#       <td>  4</td>
#       <td>          OSKM</td>
#       <td> 1</td>
#       <td> iPSC</td>
#       <td> 15390897</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.75</td>
#       <td> 119</td>
#       <td> 0.8159</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>SC11-007B.119.3.1</th>
#       <td>                    1.69 Mb bp dup

# %% [markdown]
# ##Quality Control - Covariates
# A quick perusal of the metadata seems to indicate that there is a large concordance between certain of the experimental and technical variables.  To explore this I will do a table test to look for experimental and technical variables that may be confounded.  For those that have high overlap we can look at the specific contigency tables.
#
# **note:** Even though the assumptions for performing a chi-square test instead of a Fisher exact test on each contigency table I do the former for simplicity.

# %%
chi_p_vals = np.zeros((metadata.shape[1], metadata.shape[1]))
for i, label1 in enumerate(metadata.columns):
    for j, label2 in enumerate(metadata.columns):
        if label1!=label2:
            chi_p_vals[i,j] = stats.chi2_contingency(pd.crosstab(metadata[label1].dropna(), metadata[label2].dropna()))[1]
log_chi_p_vals = np.log10(chi_p_vals)

#Plot sorted data
transformedData = log_chi_p_vals
pylab.figure(figsize=(10,10))
pylab.imshow(transformedData, interpolation='nearest'); pylab.colorbar()
pylab.xticks(range(metadata.shape[1]), metadata.columns, rotation=90)
pylab.yticks(range(metadata.shape[1]), metadata.columns)
pylab.title('Similarity betweeen covariates')
print

# %% [markdown]
# Looking at these p-values and extracting the contigency tables of the extremely significant variables below a story emerges where some of these significant associations are expected while others might be more problematic.
#
# ####Non-problematic associations:
#
#   *  **donorstage-linetype**, **donorstage-origcell**, and **origcell-linetype** are all significantly linked because all except one HESC are blastocyst which all stem from embryo.
#   *  **lane-run** This will make it hard to easily correct for run-lane effects but all lanes have been used in at least one run which means a lane specific model could be built if necesary.
#   * **vector-inductiongenes** means that we can't distinguish signals that are specific for vector or induction genes. Unfortunately these seem highly correlated with originlab as well (see below).
#
# ####More problematic overlapping annotations:
#
#   * **origlab-, -vector, -inductiongenes** Each lab predominantly uses a single set of induction genes for example the Gaude/Weis lab exlusively used OSKM
#   * **origlab-donorstage** Specific labs contribute specific samples, for example Zambidis lab is identical to neonate; Conklin is identical to adult; Gadue/Weis identical to ped
#   * **origlab-origcell** shows problems with the Zambidis UCB CD34+ samples but is evenly distributed for the fibroblasts.
#   * **run-, origcell, origlab, vector** makes it very hard to extract experimental artifacts for example 9/10 of the Zambidis samples which is also 9/10 of the UCB CD34+ samples were processed in one run.

# %%
#Display the contigency tables for the lowest p-values
html = ''
for i, j in zip(*np.where(log_chi_p_vals<-8)):
    if i>j: 
        html+= '<b>%s - %s: p<%0.3g</b>' %(metadata.columns[i], metadata.columns[j], 10**log_chi_p_vals[i,j])
        html+=(pd.crosstab(metadata.ix[:,i].dropna(),metadata.ix[:,j].dropna()).to_html())
display.HTML(html)
# Out:
# <b>linetype - donorstage: p<4.71e-12</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>linetype</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>hESC</th>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>iPSC</th>
#       <td> 8</td>
#       <td>  0</td>
#       <td> 28</td>
#       <td> 12</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table><b>origcell - donorstage: p<2.33e-18</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>origcell</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CB</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>CD34+</th>
#       <td> 2</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>UCB CD34+</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>amniotic fluid MSC</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>blastocyst</th>
#       <td> 0</td>
#       <td> 9</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>bone marrow</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>embryo</th>
#       <td> 0</td>
#       <td> 1</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>fibroblast</th>
#       <td> 5</td>
#       <td> 0</td>
#       <td> 17</td>
#       <td> 12</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origcell - linetype: p<3.79e-11</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>linetype</th>
#       <th>hESC</th>
#       <th>iPSC</th>
#     </tr>
#     <tr>
#       <th>origcell</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CB</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>CD34+</th>
#       <td> 0</td>
#       <td>  4</td>
#     </tr>
#     <tr>
#       <th>UCB CD34+</th>
#       <td> 0</td>
#       <td> 10</td>
#     </tr>
#     <tr>
#       <th>amniotic fluid MSC</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>blastocyst</th>
#       <td> 9</td>
#       <td>  0</td>
#     </tr>
#     <tr>
#       <th>bone marrow</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>embryo</th>
#       <td> 1</td>
#       <td>  0</td>
#     </tr>
#     <tr>
#       <th>fibroblast</th>
#       <td> 0</td>
#       <td> 36</td>
#     </tr>
#   </tbody>
# </table><b>origlab - donorstage: p<8.35e-13</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 3</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 2</td>
#       <td> 1</td>
#       <td>  4</td>
#       <td>  0</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Gadue/Weiss</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 12</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Kyba</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td> 0</td>
#       <td> 5</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slack</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  3</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slukvin</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Thomson</th>
#       <td> 0</td>
#       <td> 4</td>
#       <td>  8</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Torok-Storb</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Zambidis</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origlab - inductiongenes: p<5.91e-12</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>inductiongenes</th>
#       <th>OS-NL</th>
#       <th>OSK-L-l-p53KD</th>
#       <th>OSK-l-N-p53KD</th>
#       <th>OSK-l-p53KD</th>
#       <th>OSKM</th>
#       <th>OSKM - NLT</th>
#       <th>OSKM-L</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 4</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 0</td>
#       <td> 3</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>Gadue/Weiss</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 12</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Kyba</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Mayhew/Malik</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slack</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slukvin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 2</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Thomson</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 8</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Torok-Storb</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Zambidis</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  4</td>
#       <td> 6</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origlab - origcell: p<5.38e-17</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>origcell</th>
#       <th>CB</th>
#       <th>CD34+</th>
#       <th>UCB CD34+</th>
#       <th>amniotic fluid MSC</th>
#       <th>blastocyst</th>
#       <th>bone marrow</th>
#       <th>embryo</th>
#       <th>fibroblast</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  5</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 0</td>
#       <td> 2</td>

# %% [markdown]
# ###Association between covariates and Expression Data
# By looking at the principal signals in the expression data we can extract the assocation with these with each of the metadata.  I'll start by downloading the expression and processing the expression data.

# %%
#Fetch the expression data from Synapse
exprEnt =syn.get(EXPR_ID)
exprData = pd.read_csv(exprEnt.path, sep='\t', index_col=0)

#Remove samples which are not in the metadata (i.e. that failed QC or not in the where statement above)
cols = ['symbol', 'locus']; cols.extend(metadata.index)
exprData = exprData[cols]

# %% [markdown]
# Remove genes with low variance (standard deviation<.1) or where 80% samples have no expression

# %%
#Remove non protein coding genes
biomart = pd.DataFrame.from_csv('biomart_ensembl_biotype.tsv', sep='\t')
idx = biomart.index[biomart['Gene Biotype']=='protein_coding']
exprData = exprData.select(lambda i: i.split('.')[0] in idx)
print exprData.shape

#Remove genes with excessive non-expressed samples (i.e >80% of samples with 0 expression)
idx = (exprData==0).sum(1)/float(exprData.shape[1]-2) <=.2
#AND low variance across samples
idx &= (np.log2(exprData.ix[:,2:]+1).std(1)>.1)

exprData = exprData.ix[idx,:]
symbol = exprData['symbol']
locus = exprData['locus']
exprData = exprData.ix[:,2:]
print exprData.shape
# Out:
# (20276, 65)
# (15845, 63)

# %% [markdown]
# Log transform and normalize data to Z-scores

# %%
##Log transform data
logExprData = np.log2(exprData.ix[:,:]+1)
##normalize each sample to be z-score
logExprData = logExprData - logExprData.median(skipna=True)
#logExprData = logExprData/logExprData.std(skipna=True)

# %%
#Standardize each row (gene) to z-score
d = logExprData.T - logExprData.T.mean(skipna=True)
d.ix[:,:] = d.ix[:,:]/d.ix[:,:].std(skipna=True)
pylab.figure(figsize=(20,20))
#Perfrom SVD analysis
#import mpld3

#mpld3.enable_notebook()
u, s, vt = MicroArray.QaD_SVD(d.T, metadata.drop('diffnameshort', axis=1));
#mpld3.display.fig_to_d3?

# %%
#For sanity lets look at the top gender associated genes in toppGene
idx = np.argsort(u[:,1])
ToppGeneEnrichement(pd.concat([symbol[idx][:100], symbol[idx][-100:]]))
#for i in idx[-10:]:
#    df = pd.concat([exprData.ix[i,:], metadata['donorsex'], metadata['cnv'], metadata['ratio']], axis=1)
#    df.columns = ['gene', 'gender', 'cnv', 'ratio']
#    df.boxplot(['gene'], by=['gender'])
# Out:
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="CBX5 ZBTB10 PIAS1 NR6A1 KIF21A CCDC117 ACTR2 API5 GDI2 RDX TMEM123 SMCHD1 KIF5C RASA1 MAP3K7 KIF5B AGTPBP1 VEZF1 PUM2 CTNNB1 ZYG11B CKAP2 GXYLT1 PPP2R5E SMEK2 EXOC5 PPP1CB WHSC1L1 CDK13 KIDINS220 ATF2 PDS5B INTS2 USP44 ZNF654 LZIC PTPRZ1 ZFP82 LTN1 ATAD5 WASF3 PARG DEK PHF6 PRPF40A RBM26 KLF3 WDR48 OSBPL11 ZNF280B TP53BP1 LRCH2 PAPD5 ZMYM4 AKAP11 ZMYM2 SLC4A7 RFC1 PHIP SBNO1 TOP1 AP3M1 DDX6 LRRC55 BCORL1 RLF BCAT1 MAP6 PRTG TCF12 CDK8 DENND4C MSL2 ROCK1 RAD21 WAC USP24 CHD1 BAZ1B ESCO1 NIPBL NEMF HIF1A AFF2 C11orf87 SEC24B PCM1 CHN1 ANKRD32 TOP2A KIF4A NCAPG KIF18A CCDC160 GCC2 ITGA6 SPAG9 MYO1B TET1 BRAF TMEM106C PISD TCEB2 NUDT1 RPS28 FIS1 XAB2 COL9A3 NHP2 PCOLCE WDR83OS OBSL1 SLC25A39 SDC2 PACSIN3 NDUFB6 RPLP1 MRPL43 YDJC RPL18 TIMM13 MRPL52 ZNF585A NDUFA13 GAL MGST1 RPS10 TMEM258 MRPS16 SSNA1 MRPS34 ZNHIT1 ANAPC11 POLR2I RPS27A FBL MXD3 RPS5 LAMTOR4 FAM195B RPS29 REEP5 APEH POLR2F NPM3 C12orf44 ZDHHC12 MRPL38 COL18A1 PDLIM2 PIN1 ASNA1 MTX1 UQCRH RPL27A RNF7 ST6GALNAC6 DNASE2 SSR4 RAC3 VAMP5 CHPF MRPL4 RPS2 ARPC1B PROSAPIP1 SF3B5 BLOC1S1 DAZAP1 COX7C UCKL1 DMKN UBTD1 RPL8 FKBP2 RPS3 RUVBL2 RPS21 CLDN4 MRPS24 FAU RPLP2 NSUN5 MFSD10 LAGE3 LRCH4 PSMB6 NME3 NDUFS5 CAPG SEPW1 TOMM7 ATP5G1 RPS9 VAMP8 EEF1D MRPL14 RPS16 SPINT2 PRELID1">
#         <input type="submit" value="View in ToppFun">
#         </form>

# %% [markdown]
# ###Observations about the expression data
# The association between the expression data and the metadata unfortunately shows that the majority of the signal in the data is associated with experimental covariates.  Specifically we are seeing strong association between copy number variation, gender run and the ration QC metric. It should be easy to correct for these using the residuals of a linear model

# %% [markdown]
# ##Normalization based on covariates
# Fit a model of expression of each gene as a function of gender and copy number variation, that is
#
# $$Y_{gene} = \beta_0 + \beta_1\cdot X_{gender} + \beta_2\cdot X_{cnv} + Error$$
#
# The residuals of this model will contain the remaining variation in the data that is independent of gender or copy number variation.
#
# **Note** If the copy number labels are complete it would probably be better to correct for the copy number variation in those regions of the genome that are indeed duplicated instead of on a global scale.

# %%
logExprDataNorm = np.empty_like(exprData.as_matrix())
for i in range(exprData.shape[0]):
    #Build up data frame of gene and covariates
    df = pd.concat([logExprData.ix[i,:], metadata['donorsex'], metadata['cnv'], 
                    metadata['ratio'], metadata['run'], metadata['origlab']], axis=1)
    df.columns = ['gene', 'gender', 'cnv', 'ratio', 'run', 'origlab']
    #Fit model
    mod = sm.ols('gene ~ gender', df)
    res = mod.fit()
    df['res']=res.resid
    logExprDataNorm[i,:] = df['res']
    #df.boxplot(['gene','res'], by=['gender'])
logExprDataNorm = pd.DataFrame(logExprDataNorm, columns=exprData.columns, index=exprData.index)

# %% [markdown]
# ###Save output to Synapse

# %%
logExprDataNorm.to_csv('normalized_log_transformed_data.tsv', sep='\t')
file = syn.store(synapseclient.File('normalized_log_transformed_data.tsv'), used=[EXPR_ID, METADATA_ID], executed='syn2480756')
syn.onweb(file)

# %% [markdown]
# ###PCA of residuals
# Perform PCA of the normalized samples

# %%
d = logExprDataNorm.dropna(axis=1)
u, s, vt = MicroArray.QaD_SVD(d, metadata.drop('diffnameshort', axis=1).ix[d.columns,:]);

# %% [markdown]
# We can explore the genes most strongly associated with these PC by looking at the loadings in ToppGene

# %%
for i in range(2):
    topGeneIdx=argsort(u[:,i])
    display.display_html(ToppGeneEnrichement(symbol[topGeneIdx][:100], name='Anti-Correlated PC%i'%(i+1)))
    display.display_html(ToppGeneEnrichement(symbol[topGeneIdx][-100:],  name='Correlated PC%i'%(i+1)))
# Out:
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SLC16A3 DDIT4 LARGE GSTT1 PPFIA4 BNIP3 CYP26A1 H1F0 C3 RP11-553A10.1 C4orf47 MYO15B APOA1 STMN2 C19orf33 AC012360.2 GSTM1 FBXL16 PDK1 SLC22A18 CST1 NAPRT1 LHX5 P4HA2 TMEM88 GREB1L SPAG4 PLA2G6 RBP4 ANKRD37 NPTX1 IRX2 PFKFB4 APLP1 SLC39A4 MXI1 C19orf77 F12 PEX6 EGLN1 NUDT18 SULF1 TXNRD3 CDC42EP5 TMEM187 SDK2 ALDOB TRANK1 P4HA1 DLL3 IGFBP5 CD300A TTLL6 CMTM1 PIGR GATSL3 UPK1A TRPM4 SLC38A4 MEIOB TMEM54 CD40 RDM1 C6orf57 FGF11 RHOU IRX1 HSD11B1L PLA2G2A TNNI3 CFB MYCL1 INSIG2 EML2 VPS37D ANPEP STON1 ROBO3 ABHD14B NUDT7 EXD3 LDHD GPR157 FAM162A CCNG2 MORN4 BTG2 NGFR BCL6 RP11-77K12.1 NAT6 PAMR1 FAM167B CHP2 TXNIP C5orf38 PAN2 ZNF518B BBS9 BOLA1">
#         <input type="submit" value="Anti-Correlated PC1">
#         </form>
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SCG3 LRRTM3 B3GNT7 P2RY11 TAGLN VGLL3 TRIM4 RBM47 VSIG10 HRK TOE1 FHDC1 SLCO1C1 TRIM54 POMZP3 L1TD1 LANCL2 ZNF107 TEX14 VWA1 EIF1AX PCDHAC2 CYLD DCTN5 PRICKLE1 RASGRF2 ADM5 HTR1A GDF3 AF165138.7 ATF5 ACTG2 IGFBP3 ADM TM4SF18 RP11-297M9.1 GPR64 JUN FOS DTNA MCOLN3 PVRL3 C17orf51 LAMP5 SQSTM1 ZNF248 AL591025.1 HAS3 KAL1 SPP1 NCOA5 BSCL2 TXNRD2 AL353354.1 NPFFR2 MAP1B QPCT ANKRD33B NR3C1 HIST1H2BK DCLK1 FOXD3 TNFRSF11A CASP3 HMOX1 HIST1H2BJ SLC7A11 LCP1 B3GALT5 SOCS2 PHACTR2 PDGFRA MAP1A SYNJ2 ADAMTS16 UTP14A C9orf135 MEGF10 KLHL4 SELK DPF1 ZNF280D VGF PPP1R17 SERPINB9 C7orf29 AFP GNA14 HDLBP HTR7 ZNF680 LRRC61 SEPT2 PDE4B TIMP4 CXCL5 FSIP1 SPIB TYW3 CRYZ">
#         <input type="submit" value="Correlated PC1">
#         </form>
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="HDLBP SEPT2 XRCC6 WLS HLA-DQB1 PRTG ZEB2 RPSAP58 EEF1B2 LARGE ANKHD1-EIF4EBP3 SP5 GREB1L TFRC USP3 HLA-DRB1 SLIT2 SMOC1 TAF9B MAP2 TCF12 SEMA6D DPYSL5 CDH6 ZNF248 GBX2 TTC3 PCDHGC4 WNT8B CDH11 EFNA5 CCDC160 GRM3 TMEM88 ZNF518B CCDC177 C17orf96 FP15737 CNTFR FEZF1 PAX6 AL353354.1 APAF1 AP000688.1 BTBD17 TYW3 NR2F1 CENPE MSANTD3-TMEFF1 IGFBP5 AP000275.65 DCLRE1C ZNF521 CTD-2545G14.7 YAF2 NDUFS1 NOMO3 KATNAL2 FAM184A TACR3 EPB41 ENC1 NCAM1 CRYZ FZD2 MAP6 PSME3 ISY1-RAB43 KHDRBS3 FST SIPA1L2 FUT8 CDH9 DUSP6 LRIG3 ZNF681 ZNF558 LHX2 CCDC65 KIAA0408 RFXAP PCDHGB7 CXCR4 PHC2 CTD-2369P2.12 CHD7 NRIP1 CCDC88A AMPH ETV6 TSPAN11 LIX1 AKT3 ZEB1 SLC15A4 ANKRD12 FOXB1 KIF21A MDFIC PLEKHA7">
#         <input type="submit" value="Anti-Correlated PC2">
#         </form>
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="LDOC1 C17orf107 SPATC1L FLJ20373 FGF19 AURKC TNNC2 GSTO2 REC8 HSPA2 PRSS3 TF PHLDA2 PRODH ELF3 RP11-162P23.2 NR1I2 GABRP SCT CD40 GSTM1 KLK8 ACTG2 ZNF880 SPTSSB ZNF667 AFP SLC39A4 F11R STC2 C5orf38 ZNF208 CCDC169 AHSG MCAM RP11-87C12.2 LTF CHAC1 C7orf29 SYT11 PET117 ID1 DIO1 PRDM14 RCN3 PTPRN RP1-317E23.6 MT1X RP11-599B13.6 NAALADL1 TCEAL5 SERPINB9 CHCHD2 SPINK1 IZUMO2 LCP1 UCMA ZNF528 AC009133.19 TAGLN TRIML2 CTD-2162K18.4 S100A10 CLDN4 DPPA5 LGALS1 ZFP57 HHLA1 SCGB3A2 CCDC152 S100A6 GAL TRIM6 CAV1 DUSP23 CSRP1 CXCL5 ZNF585A TNFRSF12A GADD45G MT1G CR1L IRX2 MT1H FAM24B C19orf33 GPX2 IL32 SELV RBP4 CTSF CTB-102L5.4 LRRC61 RAB17 PKIB ZFP42 NNAT NLRP2 GSTT1 TSTD1">
#         <input type="submit" value="Correlated PC2">
#         </form>

# %% [markdown]
# ##Cell of origin and Induction gene analysis

# %%
def runModels(data):
    #Put the data into temporary datastructure
    df = data.T
    #I have to temporarily rename the genes to work with Patsy formulas
    df.columns = ['gene_%i' %i for i in range(len(df.columns))] 
    df['origcell'] = metadata['origcell']
    df['inductiongenes'] = metadata['inductiongenes']

    #Exclude HESCs
    #idx = metadata.linetype !='hESC'
    #df = df.ix[idx,:]
    
    def model(geneName):
        mod1 = sm.ols('%s ~ origcell' %geneName, df)
        mod2 = sm.ols('%s ~ inductiongenes' %geneName, df)
        return mod1.fit().f_pvalue, mod2.fit().f_pvalue
    
    #from multiprocessing import Pool
    #pool = Pool()
    pvals = map(model, df.columns[:-2])
    #pool.join()
    pvals = np.asarray(pvals)
    
    models = pd.DataFrame(symbol.copy())
    models['origcell']=pvals[:,0]
    models['inductiongenes']=pvals[:,1]
    return models

normPvals = runModels(logExprDataNorm)
#origPvals = runModels(logExprData)

# %% [raw]
# ##Store the pvalues to synapse
# models = pd.DataFrame(symbol.copy())
# models['coi_fdr_corrected_p (normalized data)'] = smm.multipletests(normPvals.origcell, alpha=0.05, method='fdr_bh')[1]
# models['genes_fdr_corrected_p (normalized data)'] = smm.multipletests(normPvals.inductiongenes, alpha=0.05, method='fdr_bh')[1]
#
# models['coi_fdr_corrected_p (uncorrected data)'] = smm.multipletests(origPvals.origcell, alpha=0.05, method='fdr_bh')[1]
# models['genes_fdr_corrected_p (uncorrected data)'] = smm.multipletests(origPvals.inductiongenes, alpha=0.05, method='fdr_bh')[1]
#
# models.to_csv('model_corrected_pvalues_for_shane.csv')
#
# code = syn.store(synapseclient.File('C4_qc_and_linear_models.ipynb', parent='syn1774100'))
# ent = synapseclient.File('model_corrected_pvalues_for_shane.csv', parent='syn2332184')
# ent = syn.store(ent, used=[EXPR_ID, METADATA_ID], executed=code)
# syn.onweb(ent)

# %% [markdown]
# ###Compare these models to the genelists found by Nathan

# %%
import matplotlib_venn

#Determine significant genes using Benjamini-Hochberg FDR correction
def filterPvals2GeneSymbols(pvals):
    pval_pass = smm.multipletests(pvals, alpha=0.05, method='fdr_bh')[0]
    return symbol[pval_pass]

#coi_signficant_logExprData= filterPvals2GeneSymbols(origPvals.origcell)
coi_signficant_logExprDataNorm= filterPvals2GeneSymbols(normPvals.origcell)
nathan_coi=pd.DataFrame.from_csv('COI-GeneExpression-signatures.csv')
matplotlib_venn.venn2([set(coi_signficant_logExprDataNorm),  #set(coi_signficant_logExprData), 
                       set(nathan_coi.index)], 
                       set_labels=['normalized', 'AltAnalyze']) #'unormalized', 
pylab.title('Significant Gene counts for COI')

display.display_html(ToppGeneEnrichement(coi_signficant_logExprDataNorm, name='COI'))
print set(nathan_coi.index).intersection(set(coi_signficant_logExprDataNorm))
# Out:
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="GCLC CFTR SLC4A1 DHX33 TMEM132A ZNF263 TNFRSF12A PNPLA4 NOS2 RPUSD1 TSR3 CDKL5 RPS20 KAL1 ZBTB32 KDM5D STMN4 SRCIN1 HGF CPS1 SNAPC1 PQLC2 CTNS ZIC2 OFD1 GPM6B CTPS2 KITLG PER3 FAM160A2 MSMO1 TTC17 SZRD1 GYG2 SLC2A3 GUCY1B3 ZNF112 EIF4B SPHK2 ST3GAL6 PMS1 OAT NDUFB4 CTNNA2 DDX3Y NEO1 TFE3 IFT80 SDK2 GAL FUNDC1 KIAA1107 DGCR2 RNF126 HLTF P4HA2 CLCN4 MRPS34 NOTCH3 SLC12A1 ZNF638 RGS11 GPC4 NMRK2 UBE2T CAPN6 SIRT6 AMPH OSBPL6 AFP PALB2 PIBF1 GSTP1 ATG16L1 DIMT1 PPP1R15A TRIP6 FKBP1A ZNF343 HEPH ZBTB25 HAUS4 MFSD11 DPYSL2 CECR1 CYP26A1 NUBP2 HNRNPH3 ERMP1 PSMD8 TIMM13 EIF3L POLR2F DDX17 MCAT ABHD4 CGRRF1 SRSF5 CINP NFKBIA PSME2 C20orf24 PSMA7 GMEB2 SIRPB1 PDYN NOP56 TTI1 E2F1 LAMA1 CSTF2 PSMD10 STS GPR143 NXT2 AMMECR1 CHRDL1 SUV39H1 PLS3 MTMR8 ZC3H12B PQBP1 PCSK1N SMS CDK16 KLHL4 BEX4 INTS6 LONP2 PSMD7 HAS3 NAGPA SEC14L5 CLCN7 VPS18 STMN2 LEPROTL1 BNIP3L NFKBIB DKKL1 MED26 AKAP8 CCDC94 MRPL4 CYTH2 GRWD1 JAK3 UPK1A ARMC6 SUGP1 ATP6V0A4 C1GALT1 MRPL32 YKT6 SEC61B DNMBP FBXL15 SUFU PPIF P2RX1 INTS2 MRPL27 ELF2 VWF IL23A LTA4H TRPV4 NOP2 CHPT1 RAB35 TDP2 CEP85L RNGTT KCTD20 STK38 CD83 FBXL4 MED23 BYSL GUCA1B PTK7 FAM46A PCDHB2 PAPD7 PCDHB5 PCDHB15 HAVCR1 DROSHA RAD50 TTC33 SMAD5 ATP6V0E1 HES1 USP9Y TUSC2 FXR1 CBLB KLHL18 INO80D IFIH1 OTX1 TXNDC9 CHST10 MOB4 QPCT DARS S100PBP LEPR KIAA2013 RGS2 RLF KDM5B ATP6V0B ESYT2 FILIP1 SGK1 ABCG2 PCDH17 CCND2 GTF3C3 GDA ACOT2 YPEL5 NUP43 PCDHB12 ENY2 SOHLH2 SERP1 DYNLL2 TSHZ3 LHX4 TRMT1L ZMYM2 FABP3 ZNF639 ZSCAN20 LRIF1 NAA60 ODF2L NBPF14 WIPF3 CCZ1 PRDX4 C19orf43 MORF4L2 FAM199X RAB9A NMI RAP2C DAW1 CHPF FAM210B PTGIS ZNF576 MAD2L1BP CNOT1 SEPT6 NT5C CHCHD5 GTF2F1 GRIA3 VASP TGM3 CENPB CST11 SNRPB FLRT3 ITPA MRPS26 PRDX5 BECN1 ABHD8 LRRC61 EMC6 SRD5A3 DGCR6L MCHR1 TPST2 MRPS12 RAB2B MAP7D3 RPS4Y1 DOHH HDHD1 MRPL34 SNX9 MLLT1 STK33 NDUFA10 ZSWIM6 TRPM4 ZNF337 CEP85 ADRM1 CHMP2A UBA1 TTLL9 EDA2R ABCB7 SH3BP5 KIF3A WDR44 PDHA1 MCCC2 ARFIP2 CARD6 NIP7 NXT1 TOE1 C20orf111 SLC41A1 BEX2 RNF128 FAM104A MED10 LARGE TMTC1 SPINK5 CCDC59 VRTN TTC9 MED6 CTIF ATPBD4 GSTM1 LAMTOR5 DTNA ADAMTS8 LCA5 FAIM2 HNRNPA1 TAF5L KIAA1033 LCP1 SETDB2 ZFHX2 TACO1 LIMD2 TRA2B GYPC LRRC8A TOR1A ANP32B RPL35 SIT1 KIAA0319 TAF8 BCL2L10 DYNC2LI1 SIX3 TIMM23 GLCE HCN4 PAPSS1 RNF185 GABARAPL1 PRICKLE1 GLIPR1 TARBP2 SSTR1 RAB15 WDR89 HDC DNAJA4 MESDC1 TICRR PTRH2 PMAIP1 TPGS1 ZFP14 ZNF787 NOSIP SH3BGRL3 TBX19 MGST3 SNX27 ENSA TAF1A ACP1 LEFTY2 C1orf35 PPFIA4 DUSP11 ZNF385B KANSL1L CNTN4 RBMS3 SLC25A38 CNPY2 COL8A1 PYURF UGT3A1 YIPF5 HIGD2A ABT1 RPL7L1 PRSS35 PNRC1 GNA12 C7orf50 CDCA5 NLGN4X SHROOM2 CASK ZNF182 CHST7 CCDC120 IGSF1 POLR2K EIF3H NAPRT1 CBWD5 SHC3 ZNF462 NR6A1 WDR31 POLE3 SURF1 MED22 NACC2 HTR7 SERPING1 SESN3 FRG1B SAP18 CCDC3 ACAD8 DRD3 FLI1 GABRA2 FAM168B TMEM163 HSPB8 PDK1 ZNF837 ANKRD22 CETN3 SYCP2L UBALD1 ABI3BP UCHL1 MIA3 LONRF1 CCSAP ATP5G3 SORBS2 TCEB1 TMSB4Y TSEN2 CDK19 SLC25A28 LSM11 ZDHHC5 UTP14A AIFM1 RBPMS MMP14 ARMC12 KIT ERG ETS2 BRAF FMNL2 FAM213B C12orf43 PTPDC1 FAM46B TMSB15B FAM86C1 COPG2 RNF166 FGF17 NDUFS2 SLC5A11 C21orf59 CBR1 PSMB4 TCHH CCDC117 BSDC1 ATAD3B UBE2J2 NR2F6 RRP1 NACC1 ORAI2 PLXDC1 SSTR5 AMDHD2 TPCN2 PARS2 PRKAA2 GFI1 IGSF8 RBM15 BROX PPP1R21 CAPN13 HIPK1 RNF25 NUAK2 KIAA1407 CXCL1 PLSCR2 RPL39L LRPAP1 NDST3 F2RL1 KIAA1430 GRIK2 CITED2 KIAA1324L ORC5 PHAX SLC25A32 NFIL3 GKAP1 KIF27 MID1IP1 NLGN4Y ZNF488 MICU2 ARF6 SNAPC4 GFI1B SALL2 GLB1L3 IKBIP RPUSD2 TRMT61A ASPG DCHS1 SERPINB8 TUB LMO1 CRABP1 NGFRAP1 LDHC C18orf54 DCTN5 ELFN2 TRUB2 COQ4 GPRC5B ATP5L TRIM68 ZNF610 ANKRD33 DAPK3 C19orf48 TMEM68 PRR25 ZNF598 ZNF597 FADD RAB4A DDIT4 LMBRD1 COA6 PCMTD1 DTYMK POLR3D FEN1 AXIN2 TMEM208 ZBTB5 CPT1C NSMCE1 RAB3B CD2BP2 CA5B COL22A1 MMGT1 MT1E DUS1L SYAP1 ZNF764 PUSL1 SF3B5 DENND5B CDH2 COMMD5 TMEM43 TEX13B ZNF160 JAGN1 SCAND1 MRPL36 ZBTB26 POLR1C TBCA BPTF METTL18 ZNF217 THOP1 KRCC1 NME6 CYCS POP7 SUCLG2 CLP1 MANEA ZNF738 CORO1B RAB43 CBWD1 MYD88 ZNF680 MRP63 ADCY5 ZBTB21 MINOS1 THAP2 SSSCA1 LRFN4 EIF1AX GPR64 GOLIM4  ...
#         <input type="submit" value="COI">
#         </form>
# set(['IFITM2', 'TMSB4Y', 'LARGE', 'NAPRT1', 'USP9Y', 'LRRC61', 'SORBS2', 'RPS4Y1', 'CDKL5', 'PCDHB5', 'GAL', 'CITED2', 'MT1F', 'CECR1', 'PLS3', 'DDIT4', 'DDX3Y', 'ZNF680', 'HLA-DRB1', 'LEFTY1', 'HTR7', 'MT1E', 'ACOT2', 'ACOT1', 'GSTM1', 'PDK1', 'NKX1-2', 'C9orf135', 'CYP26A1', 'KDM5D', 'HES1'])

# %%
#inductiongenes_signficant_logExprData= filterPvals2GeneSymbols(origPvals.inductiongenes)
inductiongenes_signficant_logExprDataNorm= filterPvals2GeneSymbols(normPvals.inductiongenes)
nathan_inductiongenes=pd.DataFrame.from_csv('GeneCombinations-GeneExpression-signatures.csv')
matplotlib_venn.venn2([set(inductiongenes_signficant_logExprDataNorm), #set(inductiongenes_signficant_logExprData), 
                       set(nathan_inductiongenes.index)], 
                       set_labels=['normalized', 'AltAnalyze'])
pylab.title('Significant Gene counts for Induction Genes')

# %% [markdown]
# ####Explore some of the specific different genes

# %%
diffSet = list(set(coi_signficant_logExprDataNorm) -  set(nathan_coi.index))
i = np.where(symbol==diffSet[2])[0][0]
print i
pd.concat([logExprDataNorm.ix[i,:], metadata['origcell']], axis=1).boxplot(by='origcell')
pylab.xticks(rotation=90)
#df = pd.concat([logExprData.ix[i,:], metadata['donorsex'], metadata['cnv'], metadata['ratio']], axis=1)
#df.columns = ['gene', 'gender', 'cnv', 'ratio']
# Out:
# 4013
# (array([1, 2, 3, 4, 5, 6, 7, 8]), <a list of 8 Text xticklabel objects>)

# %% [markdown]
# **Ah** This seems to be due to HESC vs iPSC - should HESC be excluded for COI analysis?
