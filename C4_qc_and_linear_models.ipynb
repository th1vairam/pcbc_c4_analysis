# %%
import synapseclient
import IPython.display as display
from IPython.core.display import display as display2
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.formula.api as sm
import MicroArray
from synapseHelpers import query2df
from toppGenePost import ToppGeneEnrichement
from multiprocessing import Pool

EXPR_ID = 'syn1968267'
METH_ID = 'syn2233188'
MIRSEQ_ID = 'syn2233189'
METADATA_ID = 'syn2248030'
pd.set_option('max_columns', 200)
syn = synapseclient.login()
pool=Pool()
# Out:
# Welcome, Larsson Omberg!

# %% [markdown]
# ##Download and annotate data
# 1. Downloads expression data from Synapse
# 2. Gets annotations from metadata in Synapse
# 3. Explore correlation between metadata fields

# %% [markdown]
# Query synapse for metadata of the expression data and store in a pandas dataframe

# %%
QUERY = 'select * from entity where passqc=="PASS" and diffnameshort=="SC" and parentId=="%s"' %METADATA_ID
metadata = query2df(syn.query(QUERY))
metadata.index = metadata['decoratedName']
metadata = metadata.drop(['decoratedName', 'name','passqc', 'bamId', 'fastqId','approvedfordiff', 
                          'pub', 'projdiff', 'projdifforiginlab', 'predifferentiatedcellname', 
                          'project',], axis=1)

#Replace text 'None' with None
metadata.replace(u'None', np.nan, inplace=True)

#Simplify certain disease labels
metadata.diffnameshort[metadata.diffnameshort=='EB-LF']='EB'
metadata.diffnameshort[metadata.diffnameshort=='SC-LF']='SC'
metadata.diffnameshort[metadata.diffnameshort=='SC-hpx']='SC'
#Display a table of metadata
display.HTML(metadata.to_html())#[['inductiongenes', 'donorsex', 'diffnameshort', 'donorstage', 'linetype', 'origcell']].to_html())
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/common.py:228: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   mask = arr == x
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cnv</th>
#       <th>diffnameshort</th>
#       <th>disease</th>
#       <th>donorsex</th>
#       <th>donorstage</th>
#       <th>dysr</th>
#       <th>ethnic</th>
#       <th>index</th>
#       <th>inductiongenes</th>
#       <th>lane</th>
#       <th>linetype</th>
#       <th>numberofreads</th>
#       <th>origcell</th>
#       <th>origlab</th>
#       <th>othertx</th>
#       <th>ratio</th>
#       <th>run</th>
#       <th>uniquelyalignedreads</th>
#       <th>vector</th>
#     </tr>
#     <tr>
#       <th>decoratedName</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>H9.119.5.3</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  3</td>
#       <td>           NaN</td>
#       <td> 5</td>
#       <td> hESC</td>
#       <td> 12741696</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.77</td>
#       <td> 119</td>
#       <td> 0.8502</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.102.2.5</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  5</td>
#       <td>           NaN</td>
#       <td> 2</td>
#       <td> hESC</td>
#       <td> 13133957</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.98</td>
#       <td> 102</td>
#       <td> 0.8445</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.119.3.7</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  7</td>
#       <td>           NaN</td>
#       <td> 3</td>
#       <td> hESC</td>
#       <td> 20573989</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.74</td>
#       <td> 119</td>
#       <td> 0.8357</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>H9.102.2.6</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  6</td>
#       <td>           NaN</td>
#       <td> 2</td>
#       <td> hESC</td>
#       <td> 14141247</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.95</td>
#       <td> 102</td>
#       <td> 0.8425</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>IPS18-4-2.102.2.4</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>    NaN</td>
#       <td>      NaN</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  4</td>
#       <td>          OSKM</td>
#       <td> 2</td>
#       <td> iPSC</td>
#       <td> 10866320</td>
#       <td>              CD34+</td>
#       <td>    Mayhew/Malik</td>
#       <td>   .</td>
#       <td> 0.97</td>
#       <td> 102</td>
#       <td> 0.8409</td>
#       <td>               lenti</td>
#     </tr>
#     <tr>
#       <th>SC11-009A.133.3.5</th>
#       <td> 719kb Mosaic Duplication at 15q11.2; Mosaic mo...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>  neonate</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  5</td>
#       <td>    OSKM - NLT</td>
#       <td> 3</td>
#       <td> iPSC</td>
#       <td> 13015460</td>
#       <td>          UCB CD34+</td>
#       <td>        Zambidis</td>
#       <td>   .</td>
#       <td> 0.85</td>
#       <td> 133</td>
#       <td> 0.7737</td>
#       <td>             plasmid</td>
#     </tr>
#     <tr>
#       <th>H9.144.7.7</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>   embryo</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  7</td>
#       <td>           NaN</td>
#       <td> 7</td>
#       <td> hESC</td>
#       <td> 23118896</td>
#       <td>         blastocyst</td>
#       <td>             N/A</td>
#       <td>   .</td>
#       <td> 0.97</td>
#       <td> 144</td>
#       <td> 0.7930</td>
#       <td>                 NaN</td>
#     </tr>
#     <tr>
#       <th>SC11-008B.149.3.14</th>
#       <td> 719kb Mosaic Duplication at 15q11.2; Mosaic mo...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>  neonate</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td> 14</td>
#       <td>    OSKM - NLT</td>
#       <td> 3</td>
#       <td> iPSC</td>
#       <td>  9426723</td>
#       <td>          UCB CD34+</td>
#       <td>        Zambidis</td>
#       <td>   .</td>
#       <td> 0.94</td>
#       <td> 149</td>
#       <td> 0.7578</td>
#       <td>             plasmid</td>
#     </tr>
#     <tr>
#       <th>IPS18-4-1.102.2.2</th>
#       <td>                                               NaN</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td>    NaN</td>
#       <td>      NaN</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td>  2</td>
#       <td>          OSKM</td>
#       <td> 2</td>
#       <td> iPSC</td>
#       <td> 14066561</td>
#       <td>              CD34+</td>
#       <td>    Mayhew/Malik</td>
#       <td>   .</td>
#       <td> 0.95</td>
#       <td> 102</td>
#       <td> 0.8459</td>
#       <td>               lenti</td>
#     </tr>
#     <tr>
#       <th>SC11-002A.133.1.2</th>
#       <td>                                            normal</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>      ped</td>
#       <td>           Trisomy 12 in 2 of 20</td>
#       <td>  Caucasian</td>
#       <td>  2</td>
#       <td>          OSKM</td>
#       <td> 1</td>
#       <td> iPSC</td>
#       <td> 17676706</td>
#       <td>         fibroblast</td>
#       <td>     Gadue/Weiss</td>
#       <td>   .</td>
#       <td> 0.93</td>
#       <td> 133</td>
#       <td> 0.8244</td>
#       <td> lenti (Cre-excised)</td>
#     </tr>
#     <tr>
#       <th>SC11-010B.149.5.18</th>
#       <td> 719kb Mosaic Duplication at 15q11.2; 155 Mb Mo...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>  neonate</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td> 18</td>
#       <td>    OSKM - NLT</td>
#       <td> 5</td>
#       <td> iPSC</td>
#       <td> 22630274</td>
#       <td>          UCB CD34+</td>
#       <td>        Zambidis</td>
#       <td>   .</td>
#       <td> 1.00</td>
#       <td> 149</td>
#       <td> 0.8024</td>
#       <td>             plasmid</td>
#     </tr>
#     <tr>
#       <th>SC11-010A.149.5.16</th>
#       <td> 719kb Mosaic Duplication at 15q11.2; 155 Mb Mo...</td>
#       <td> SC</td>
#       <td>  normal</td>
#       <td> female</td>
#       <td>  neonate</td>
#       <td>                          normal</td>
#       <td>        NaN</td>
#       <td> 16</td>
#       <td>    OSKM - NLT</td>
#       <td> 5</td>
#       <td> iPSC</td>
#       <td> 21352468</td>
#       <td>          UCB CD34+</td>
#       <td>        Zambidis</td>
#       <td>   .</td>
#       <td> 0.99</td>
#       <td> 149</td>
#       <td> 0.8000</td>
#       <td>             plasmid</td>
#     </tr>
#     <tr>
#       <th>SC11-007B.119.3.1</th>
#       <td>                    1.69 Mb bp dupl

# %% [markdown]
# ##Quality Control - Covariates
# A quick perusal of the metadata seems to indicate that there is a large concordance between certain of the experimental and technical variables.  To explore this I will do a table test to look for experimental and technical variables that may be confounded.  For those that have high overlap we can look at the specific contigency tables.
#
# **note:** Even though the assumptions for performing a chi-square test instead of a Fisher exact test on each contigency table I do the former for simplicity.

# %%
chi_p_vals = np.zeros((metadata.shape[1], metadata.shape[1]))
for i, label1 in enumerate(metadata.columns):
    for j, label2 in enumerate(metadata.columns):
        if label1!=label2:
            chi_p_vals[i,j] = stats.chi2_contingency(pd.crosstab(metadata[label1].dropna(), metadata[label2].dropna()))[1]
log_chi_p_vals = np.log10(chi_p_vals)

#Plot sorted data
transformedData = log_chi_p_vals
pylab.figure(figsize=(10,10))
pylab.imshow(transformedData, interpolation='nearest'); pylab.colorbar()
pylab.xticks(range(metadata.shape[1]), metadata.columns, rotation=90)
pylab.yticks(range(metadata.shape[1]), metadata.columns)
pylab.title('Similarity betweeen covariates')
print

# %% [markdown]
# Looking at these p-values and extracting the contigency tables of the extremely significant variables below a story emerges where some of these significant associations are expected while others might be more problematic.
#
# ####Non-problematic associations:
#
#   *  **donorstage-linetype**, **donorstage-origcell**, and **origcell-linetype** are all significantly linked because all except one HESC are blastocyst which all stem from embryo.
#   *  **lane-run** This will make it hard to easily correct for run-lane effects but all lanes have been used in at least one run which means a lane specific model could be built if necesary.
#   * **vector-inductiongenes** means that we can't distinguish signals that are specific for vector or induction genes. Unfortunately these seem highly correlated with originlab as well (see below).
#
# ####More problematic overlapping annotations:
#
#   * **origlab-, -vector, -inductiongenes** Each lab predominantly uses a single set of induction genes for example the Gaude/Weis lab exlusively used OSKM
#   * **origlab-donorstage** Specific labs contribute specific samples, for example Zambidis lab is identical to neonate; Conklin is identical to adult; Gadue/Weis identical to ped
#   * **origlab-origcell** shows problems with the Zambidis UCB CD34+ samples but is evenly distributed for the fibroblasts.
#   * **run-, origcell, origlab, vector** makes it very hard to extract experimental artifacts for example 9/10 of the Zambidis samples which is also 9/10 of the UCB CD34+ samples were processed in one run.

# %%
#Display the contigency tables for the lowest p-values
html = ''
for i, j in zip(*np.where(log_chi_p_vals<-8)):
    if i>j: 
        html+= '<b>%s - %s: p<%0.3g</b>' %(metadata.columns[i], metadata.columns[j], 10**log_chi_p_vals[i,j])
        html+=(pd.crosstab(metadata.ix[:,i].dropna(),metadata.ix[:,j].dropna()).to_html())
display.HTML(html)
# Out:
# <b>linetype - donorstage: p<4.71e-12</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>linetype</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>hESC</th>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>iPSC</th>
#       <td> 8</td>
#       <td>  0</td>
#       <td> 28</td>
#       <td> 12</td>
#       <td> 1</td>
#     </tr>
#   </tbody>
# </table><b>origcell - donorstage: p<2.33e-18</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>origcell</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CB</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>CD34+</th>
#       <td> 2</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>UCB CD34+</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>amniotic fluid MSC</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>blastocyst</th>
#       <td> 0</td>
#       <td> 9</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>bone marrow</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>embryo</th>
#       <td> 0</td>
#       <td> 1</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>fibroblast</th>
#       <td> 5</td>
#       <td> 0</td>
#       <td> 17</td>
#       <td> 12</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origcell - linetype: p<3.79e-11</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>linetype</th>
#       <th>hESC</th>
#       <th>iPSC</th>
#     </tr>
#     <tr>
#       <th>origcell</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>CB</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>CD34+</th>
#       <td> 0</td>
#       <td>  4</td>
#     </tr>
#     <tr>
#       <th>UCB CD34+</th>
#       <td> 0</td>
#       <td> 10</td>
#     </tr>
#     <tr>
#       <th>amniotic fluid MSC</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>blastocyst</th>
#       <td> 9</td>
#       <td>  0</td>
#     </tr>
#     <tr>
#       <th>bone marrow</th>
#       <td> 0</td>
#       <td>  1</td>
#     </tr>
#     <tr>
#       <th>embryo</th>
#       <td> 1</td>
#       <td>  0</td>
#     </tr>
#     <tr>
#       <th>fibroblast</th>
#       <td> 0</td>
#       <td> 36</td>
#     </tr>
#   </tbody>
# </table><b>origlab - donorstage: p<8.35e-13</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>donorstage</th>
#       <th>adult</th>
#       <th>embryo</th>
#       <th>neonate</th>
#       <th>ped</th>
#       <th>prenatal</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 3</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 2</td>
#       <td> 1</td>
#       <td>  4</td>
#       <td>  0</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>Gadue/Weiss</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 12</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Kyba</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>N/A</th>
#       <td> 0</td>
#       <td> 5</td>
#       <td>  0</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slack</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  3</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slukvin</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Thomson</th>
#       <td> 0</td>
#       <td> 4</td>
#       <td>  8</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Torok-Storb</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Zambidis</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 10</td>
#       <td>  0</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origlab - inductiongenes: p<5.91e-12</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>inductiongenes</th>
#       <th>OS-NL</th>
#       <th>OSK-L-l-p53KD</th>
#       <th>OSK-l-N-p53KD</th>
#       <th>OSK-l-p53KD</th>
#       <th>OSKM</th>
#       <th>OSKM - NLT</th>
#       <th>OSKM-L</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 4</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 0</td>
#       <td> 3</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>Gadue/Weiss</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 12</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Kyba</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Mayhew/Malik</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slack</th>
#       <td> 1</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Slukvin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 2</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Thomson</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 8</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Torok-Storb</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 1</td>
#       <td> 0</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>Zambidis</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  4</td>
#       <td> 6</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table><b>origlab - origcell: p<5.38e-17</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>origcell</th>
#       <th>CB</th>
#       <th>CD34+</th>
#       <th>UCB CD34+</th>
#       <th>amniotic fluid MSC</th>
#       <th>blastocyst</th>
#       <th>bone marrow</th>
#       <th>embryo</th>
#       <th>fibroblast</th>
#     </tr>
#     <tr>
#       <th>origlab</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Conklin</th>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td>  5</td>
#     </tr>
#     <tr>
#       <th>Daley/Schlaeger</th>
#       <td> 0</td>
#       <td> 2</td>

# %% [markdown]
# ###Association between covariates and Expression Data
# By looking at the principal signals in the expression data we can extract the assocation with these with each of the metadata.  I'll start by downloading the expression and processing the expression data.

# %%
#Fetch the expression data from Synapse
exprEnt =syn.get(EXPR_ID)
exprData = pd.read_csv(exprEnt.path, sep='\t', index_col=0)

#Remove samples which are not in the metadata (i.e. that failed QC or not in the where statement above)
cols = ['symbol', 'locus']; cols.extend(metadata.index)
exprData = exprData[cols]

# %% [markdown]
# Remove genes with low variance (standard deviation<.1) or where 80% samples have no expression

# %%
#Remove genes with excessive non-expressed samples (i.e >80% of samples with 0 expression)
idx = (exprData==0).sum(1)/float(exprData.shape[1]-2) <=.2
#AND low variance across samples
idx &= (np.log2(exprData.ix[:,2:]+1).std(1)>.1)

exprData = exprData.ix[idx,:]
symbol = exprData['symbol']
locus = exprData['locus']
exprData = exprData.ix[:,2:]
print exprData.shape
# Out:
# (20720, 63)

# %% [markdown]
# Log transform and normalize data to Z-scores

# %%
##Log transform data
logExprData = np.log2(exprData.ix[:,:]+1)
##normalize each sample to be z-score
logExprData = logExprData - logExprData.mean(skipna=True)
logExprData.ix[:,:] = logExprData.ix[:,:]/logExprData.ix[:,:].std(skipna=True)

# %%
reload(MicroArray)
#Standardize each row (gene) to z-score
d = logExprData.T - logExprData.T.mean(skipna=True)
d.ix[:,:] = d.ix[:,:]/d.ix[:,:].std(skipna=True)
pylab.figure(figsize=(20,20))
u, s, vt = MicroArray.QaD_SVD(d.T, metadata.drop('diffnameshort', axis=1));

# %%
#For sanity lets look at the top gender associated genes in toppGene
idx = np.argsort(u[:,1])
ToppGeneEnrichement(pd.concat([symbol[idx][:100], symbol[idx][-100:]]))
#for i in idx[-10:]:
#    df = pd.concat([exprData.ix[i,:], metadata['donorsex'], metadata['cnv'], metadata['ratio']], axis=1)
#    df.columns = ['gene', 'gender', 'cnv', 'ratio']
#    df.boxplot(['gene'], by=['gender'])
# Out:
# <form action="http://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="ACTR2 CTNNB1 GDI2 TMEM123 NR6A1 ZBTB10 MAP3K7 API5 WASF3 PARG KIF5B KIF21A CBX5 PRPF40A DEK RAD21 RP11-265M18.2 AGTPBP1 PIAS1 RLF CCDC117 RDX PPP1CB LZIC PTPRZ1 VBP1 AP3M1 ZNF654 SMEK2 RASA1 ZFP82 ATAD5 TOP2A PDS5B BCORL1 PRTG INTS2 VEZF1 KIF5C PHF6 MAP6 CDK8 PUM2 ZNF280B ATF2 LRCH2 SLC4A7 CKAP2 ZMYM2 RBM26 WHSC1L1 SMCHD1 ESCO1 CDK13 EXOC5 BOD1 CHD1 TOP2B HDGFRP3 FBXO43 KLF3 HIF1A CHN1 SUFU KBTBD11 PRKAA2 TCERG1 PPP2R5E OSBPL11 NIPBL TCF12 CSNK2A1 KIDINS220 SLC39A6 SEC24B WDR48 NARG2 PSIP1 VAPA TARDBP SF3B3 WAC CAND1 STT3B ZNF280C ZYG11B DYNC1I2 C3orf70 NCAPG NEMF BUB1 AMOT GXYLT1 TP53BP1 LCORL RFC1 PAPD5 FUT8 USP44 SMC3 POLR2I ZNF593 RP11-267L5.1 PACSIN3 IMP4 TAGLN RPS9 TMEM106C BYSL SPARC SEC14L4 FIS1 TUBB6 WBSCR22 ARPC1B FAU ATP5D STUB1 ACOT8 TNNC2 VAMP5 MRPS12 FKBP2 RPS16 DNASE2 PROSAPIP1 AC005062.2 PSMD8 SOX15 SNRPB SSNA1 AC133919.6 MPV17L2 ADCY8 CENPW SDC2 PCOLCE MRPS16 BLOC1S1 ZNHIT1 PIN1 LMAN2 DBNDD1 CCL28 TIMM50 POLR2L EIF6 COMTD1 AURKAIP1 ITM2C YDJC WDR83OS COL18A1 RAC3 ASNA1 PSMB6 MRPL12 SEPW1 GAS8 UQCRH CRIM1 ZNF585A PDZD4 NHP2 CLDN4 NME3 SF3B5 PFN1 DMKN RUVBL2 NDUFS5 PPIB C12orf44 UPP1 PISD EEF1D RP4-792G4.2 MRPL38 MXD3 TPCN2 MRPS24 SPINT2 LAGE3 REEP5 MRPL4 CAPG CHPF RNF7 TIMM13 GAL POLR2F UCKL1 LRCH4 MRPS34 NSUN5 TOMM7 ATP5G1 VAMP8 MRPL14 PRELID1">
#         <input type="submit" value="View in ToppFun">
#         </form>

# %% [markdown]
# ###Observations about the expression data
# The association between the expression data and the metadata unfortunately shows that the majority of the signal in the data is associated with experimental covariates.  Specifically we are seeing strong association between copy number variation, gender run and the ration QC metric. It should be easy to correct for these using the residuals of a linear model

# %% [markdown]
# ##Normalization based on covariates
# Fit a model of expression of each gene as a function of gender and copy number variation, that is
#
# $$Y_{gene} = \beta_0 + \beta_1\cdot X_{gender} + \beta_2\cdot X_{cnv} + Error$$
#
# The residuals of this model will contain the remaining variation in the data that is independent of gender or copy number variation.
#
# **Note** If the copy number labels are complete it would probably be better to correct for the copy number variation in those regions of the genome that are indeed duplicated instead of on a global scale.

# %%
logExprDataNorm = np.empty_like(exprData.as_matrix())
for i in range(exprData.shape[0]):
    #Build up data frame of gene and covariates
    df = pd.concat([logExprData.ix[i,:], metadata['donorsex'], metadata['cnv'], metadata['ratio']], axis=1)
    df.columns = ['gene', 'gender', 'cnv', 'ratio']
    #Fit model
    mod = sm.ols('gene ~ gender + cnv', df)
    res = mod.fit()
    df['res']=res.resid
    logExprDataNorm[i,:] = df['res']
    #df.boxplot(['gene','res'], by=['gender'])
logExprDataNorm = pd.DataFrame(logExprDataNorm, columns=exprData.columns, index=exprData.index)

# %% [markdown]
# ###PCA of residuals
# Perform PCA of the normalized samples

# %%
d = logExprDataNorm.dropna(axis=1)
u, s, vt = MicroArray.QaD_SVD(d, metadata.drop('diffnameshort', axis=1).ix[d.columns,:]);

# %% [markdown]
# We can explore the genes most strongly associated with these PC by looking at the loadings in ToppGene

# %%
for i in range(2):
    topGeneIdx=argsort(u[:,i])
    display.display_html(ToppGeneEnrichement(symbol[topGeneIdx][:100], name='Anti-Correlated PC%i'%(i+1)))
    display.display_html(ToppGeneEnrichement(symbol[topGeneIdx][-100:],  name='Correlated PC%i'%(i+1)))
# Out:
# <form action="http://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="snoU13 SNORA63 NLRP2 AC007216.1 SNORD54 SNORA4 ZFP42 SNORA27 SNORD87 SNORD15B RP11-603J24.18 SNORA13 MIR4700 SNORD60 LRRC61 MIR3614 MIR302C PKIB SNORA11 MEG3 AC092117.2 SERPINB9 MT1H MT1G CXCL5 MIR302D CHCHD2 C9orf64 MT1X U2 RN7SL593P SNORD16 THBS1 AL591025.1 FAM20A AC100830.5 TMSB4Y ID1 Y_RNA MCOLN3 INHBE GPX2 SOCS2 CTB-102L5.4 MTND4P12 STC2 TSTD1 SNORD87 CHAC1 CTD-2501M5.1 TFRC FOS SNORD83B RP11-267L5.1 SNORA25 MT1F EGR1 IRX2 CAV1 SNORA57 RP11-158J3.2 HSP90AA6P ACTC1 RP11-132A1.3 RP1-317E23.6 SHISA3 SNORA5C PPP1R3B snoU13 ID4 C7orf29 AF165138.7 ZNF208 U6 SGMS2 SNORD88B ZNF649 SERPINE1 SLC7A11 AC005062.2 SNORA73A HMOX1 IL6ST AC016683.6 ACTG2 CH25H ACTA1 C5orf38 PRDM14 MCAM ZNF528 SPIB CSRP1 SLC16A10 RBM46 SERPINB4 DPF1 RP11-701H24.5 PLA2G16 RP11-110I1.5">
#         <input type="submit" value="Anti-Correlated PC1">
#         </form>
# <form action="http://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SLC2A3P1 LDB2 SHISA2 AC015688.3 ZEB1-AS1 DMXL2 INPP5D C6orf57 SEMA6C DPYSL5 EFNA2 GNAZ OPN3 VASH1 ASIC1 STON1 FEZF1 SNORA10 TRBV26OR9-2 RP11-85F14.5 GREB1L SNORD76 SP5 NCAM1 BNIP3 ZNF702P RP11-145M4.1 RP11-255H23.2 FAM160B2 GLYATL1 ERLEC1P1 SNORD10 ADSSL1 EFS H1F0 SLC29A4 RP1-152L7.5 MVP RP11-82L7.4 GATC KIAA1211 NUDT7 CCNG2 KATNAL2 SULF1 MIR3615 SNORD100 ZNF518B DICER1-AS1 USP3 AP000347.4 MIR210HG CST1 BTBD17 LRRC20 PRTG CUZD1 STMN2 GBX2 NBR2 TXNRD3 MIR641 NR2F1 IGFBP5 ATP1A2 SNORA81 GRM3 SNORD23 MIR3652 RP11-168A11.4 PYGO2 TMBIM4 SLC16A3 RP11-9M16.2 SNORD83A MIR671 MIR621 AL122015.1 WLS NPTX1 XRCC6 MIR4721 Y_RNA MT-TF SNORD78 SHC1 GSTT1 SNORD94 SNORA76 SNORA33 U6 SNORD35B SNORD47 CTD-2224J9.4 SNORD28 MIR4751 AC107016.2 MIR4664 SNORD36A SNORD36C">
#         <input type="submit" value="Correlated PC1">
#         </form>
# <form action="http://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SNORD36C SNORD80 SNORD87 SNORD36A SNORD35B EEF1B2 EPB41 TFRC SNORD12 SNORD60 SNORD78 TDGF1P3 FAM19A5 MIR4517 NDUFS1 MIR3655 CTB-36O1.7 MIR302A CYP26A1 Y_RNA AP000459.4 MIR4721 TMEM200B MGA RNA28S5 PSME3 SCARNA22 MIR600 MIR1306 ZFP42 SNORA61 snoU13 CTD-2561J22.2 SNORD16 U6 AC092117.2 CHCHD2 SHC1 AC007216.1 ISY1-RAB43 SHISA6 GCSHP3 GSTM1 BECN1 SNORA64 MIR663A MIR4461 ZNF788 RP11-82C23.2 AL122015.1 RP11-392P7.6 AL021707.1 CTD-2369P2.12 SCARNA16 GLT1D1 RP11-538I12.2 PYGO2 ZNF559 C5orf38 SNORD76 PDK1 HDLBP NNAT LEF1 CTD-2245F17.3 KIAA0040 FEZF1 MSANTD3-TMEFF1 TMSB4XP8 GREB1L RP4-714D9.2 LINC00674 SNORA25 CYP4F22 SLC15A4 WBSCR27 CTC-260E6.6 CTD-2349P21.10 AC007383.4 MX2 RP11-575L7.8 RHBDL3 MT1H LEPREL1 CTC-260E6.10 RP3-410C9.1 LHX5 MIR5047 BST2 CTD-2224J9.4 ANKHD1-EIF4EBP3 RP11-297M9.1 AL162497.1 MEG3 H19 SEPT2 CCDC177 PCDH10 USP47 ZNF826P">
#         <input type="submit" value="Anti-Correlated PC2">
#         </form>
# <form action="http://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="AC009133.19 RP11-463D19.2 ECSCR HHLA1 PET117 SNORA32 AC068491.1 AC012379.1 RP11-599B13.6 LYZ SNORD3A AC037459.4 EEF1E1-MUTED SNORA81 RP11-162P23.2 RP3-510D11.2 SNORA63 FAM217A SNORD50B SNORA74A CTC-345K18.2 AC003029.1 SELV NDUFC2-KCTD14 MIR4697 GAL SNORA3 PI4KAP2 RWDD2B ZNF286A SNORA11 RP11-77K12.1 DPEP1 FXYD3 SCARNA12 PRAP1 CFLAR-AS1 TUBBP5 SNORA24 AC005276.1 HMSD MTND4P24 SNORD116-21 Y_RNA TFF3 RP11-80H5.5 RP11-46C20.1 BARD1 SPINK4 SNORD30 Y_RNA AL590235.1 APOA1 SNORA67 FAM24B GPX2 SNORA16A MIR1181 RAB17 LINC00152 SPINK1 LGALS4 SNORD15B LRRC61 SNORA52 AC007773.2 ALDOB RP11-603J24.18 SNORD94 SNORD100 C19orf33 IL32 SNORD68 S100A6 RP11-1035H13.3 snoU13 SNORD104 AC012360.2 SNORD23 SNORD83A CTSF MIR4664 SNORD28 RNASEK-C17orf49 SNORD33 MIR3615 SNORA13 SNORA5C MIR762 AC005618.1 RP11-313J2.1 MIR4724 Y_RNA SNORD4A MIR4751 SNORD6 RNA5SP244 MIR4700 MIR302D MIR3652">
#         <input type="submit" value="Correlated PC2">
#         </form>

# %% [markdown]
# ##Cell of origin and Induction gene analysis

# %%
# %%time
#Put the data into temporary datastructure
df = logExprDataNorm.T
#I have to temporarily rename the genes to work with Patsy formulas
df.columns = ['gene_%i' %i for i in range(len(df.columns))] 
df['origcell'] = metadata['origcell']
df['inductiongenes'] = metadata['inductiongenes']

def model(geneName):
    mod1 = sm.ols('%s ~ origcell' %geneName, df)
    mod2 = sm.ols('%s ~ inductiongenes' %geneName, df)
    return mod1.fit().f_pvalue, mod2.fit().f_pvalue
    
pvals = np.asarray(pool.map(model, df.columns[:-2]))
    
models = pd.DataFrame(symbol.copy())
models['origcell_models']=pvals[:,0]
models['inductiongenes_models']=pvals[:,1]
#models['p_origcell'] = [x.f_pvalue for x in model_origcell]
#models['p_inductiongenes']=[x.f_pvalue for x in model_inductiongenes]
# Out:
# CPU times: user 317 ms, sys: 88.3 ms, total: 405 ms
# Wall time: 1min 42s
