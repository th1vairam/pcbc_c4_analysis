# %%
import synapseclient
import numpy as np
import pandas as pd
import scipy.stats as stats
import hierarchical_clustering as clust
import MicroArray
from toppGenePost import ToppGeneEnrichement
from IPython.display import HTML

EXPR_ID = 'syn2247799' #private'syn1968267'
EXPR_META_ID = 'syn2278178'
METH_ID = 'syn2233188'
METH_META_ID = 'syn2677043'
MIRSEQ_ID = 'syn2247832' #Private 'syn2233189'
MIRSEQ_META_ID = 'syn2278179'
BIOMART_ANNOT_ID = 'syn2706233'
pd.set_option('max_columns', 200)
syn = synapseclient.login()
# Out:
# Welcome, Larsson Omberg!

# %% [markdown]
# #Download and annotate data
# 1. Downloads expression/miRNA-Seq/methylation data from Synapse
# 2. Gets annotations from metadata in Synapse
# 3. Make sure the metadata matches up with samples

# %%
mirseq = pd.read_csv(syn.get(MIRSEQ_ID).path, sep='\t', index_col=0)
mirseq_meta = pd.read_csv(syn.get(MIRSEQ_META_ID).path, sep='\t',index_col=0)
mirseq_meta = mirseq_meta.ix[mirseq.columns,:]
mirseq_meta.drop(['Related C4 ID comment'],1, inplace=True)
print 'Mirseq Data Size:', mirseq.shape, mirseq_meta.shape
rnaseq = pd.read_csv(syn.get(EXPR_ID).path, sep='\t', index_col=[0,1,2])
rnaseq_meta = pd.read_csv(syn.get(EXPR_META_ID).path, sep='\t',index_col=0)
rnaseq_meta = rnaseq_meta.ix[rnaseq.columns,:]
print 'RNA-Seq Data Size:', rnaseq.shape, rnaseq_meta.shape
methyl = pd.read_csv(syn.get(METH_ID).path, sep='\t', index_col=0)
methyl_meta = pd.read_csv(syn.get(METH_META_ID).path, sep='\t',index_col=0)
methyl_meta = methyl_meta.ix[methyl.columns,:]
print 'Methylation Data Size:', methyl.shape, methyl_meta.shape
# Out:
# Mirseq Data Size: (2306, 127) (127, 38)
# RNA-Seq Data Size:
#  (57250, 219) (219, 37)
# Methylation Data Size:
#  (485512, 92) (92, 38)

# %% [markdown]
# #Data exploration, Quality assesement and Normalization

# %% [markdown]
# ###micro RNA-Seq

# %%
mirseq[mirseq.isnull()]=0
#microRNA probes where >10% of samples have more than 2 reads
idx = (sum(mirseq<2, axis=1)/mirseq.shape[1])<=.90
mirseq_norm=mirseq[idx]
print 'filterted down to', sum(idx), 'probes based on low coverage probes'

#Try normalization by 90 quantile
mirseq_norm = mirseq_norm/np.percentile(mirseq_norm, 90, axis=0)
#Normalize by total expression
#mirseq_norm = mirseq_norm/mirseq_norm.sum()*max(sum(mirseq_norm))
#Scale the arrays by mean and std.
mirseq_norm = MicroArray.scale(mirseq_norm)
u,s,vt=MicroArray.QaD_SVD(mirseq_norm, mirseq_meta, plotEigengenes=False)

#Filter down features to high variance ones and perform hierarchical clustering
variance = mirseq_norm.var(axis=1)
x = mirseq_norm[variance>np.percentile(variance, 95)]
clust.heatmap(x.as_matrix(), list(x.index), list(x.columns), filename='foo.png')
# Out:
# filterted down to 1302 probes based on low coverage probes
#
# Performing hiearchical clustering using euclidean for columns and cityblock for rows
# Column clustering completed in 0.4 seconds
# Row clustering completed in 0.2 seconds
# Exporting:
#  Clustering-foo-hierarchical_euclidean_cityblock.pdf

# %% [markdown]
# ###RNA-Seq

# %%
##Remove a sample with problematic karyotype
rnaseq = rnaseq.drop(['SC12-040.420.12.19', 'SC11-008DE.134.5.18'], 1)
rnaseq_meta = rnaseq_meta.drop(['SC12-040.420.12.19', 'SC11-008DE.134.5.18'], 0)

##Remove non protein coding genes
biomart = pd.DataFrame.from_csv(syn.get(BIOMART_ANNOT_ID).path, sep='\t')
idx = biomart.index[biomart['Gene Biotype']=='protein_coding']
#Filter use first index of multindex hence i[0] remove the Ensemble id text behind '.'  
exprData = rnaseq.select(lambda i: i[0].split('.')[0] in idx)
print 'RNA-Seq was filtered from', len(rnaseq), 'features to', len(exprData), 'protein coding genes'

#Filter out genes with close to zero expression
idx = sum(exprData<=3, 1)/exprData.shape[1]>.90
print 'There were %i genes with 99%% of samples having RPKM < 3 of these' %sum(idx)
print '%i genes the mean expression was %0.2g and median %0.2g' %(sum(idx), np.mean(np.mean(exprData[idx])), 
                                                                  np.median(exprData[idx]))
exprData = exprData[~idx]
print exprData.shape

#Log Transform data and standardize
logExprData = np.log2(exprData.ix[:,:]+.00001)
logExprData = MicroArray.scale(logExprData)

#Remove control samples and look at PCs
idx = (rnaseq_meta['GroupLevel1 DifferentiationState']!='PrimaryCellCulture')
d=logExprData.ix[:,idx]
d_meta = rnaseq_meta.ix[idx,:]
u,s,vt=MicroArray.QaD_SVD(d, d_meta, plotEigengenes=False)
# Out:
# RNA-Seq was filtered from 57250 features to 20276 protein coding genes
# There were 7034 genes with 99% of samples having RPKM < 3 of these
# 7034 genes the mean expression was 0.38 and median 0.023
# (13242, 217)

# %% [markdown]
# Observations: Once we drop the control samples the first through 4th PC capture EB vs SC, EB vs SC, SC/EB vs MESO, ECTO vs rest respectively.  Together these capture 85% of the information.  PC1 seems to have an outlier (SC11-008DE.134.5.18) but removing this sample shows the same trend which seems to indicate that this sample is not driving the first PC just project onto it strongly.

# %% [markdown]
# ####RNA-Seq Enrichment

# %%
symbol = d.index.get_level_values(1)
idx2 = np.argsort(u[:,1])
idx3 = np.argsort(u[:,2])
idx4 = np.argsort(u[:,3])
HTML('<table><tr><td>'+
     ToppGeneEnrichement(symbol[idx2][:100], name='Correlated PC2')._repr_html_()+'</td><td>'+
     ToppGeneEnrichement(symbol[idx2][-100:], name='Anti-Corr PC2')._repr_html_()+'</td></tr><tr><td>'+
     ToppGeneEnrichement(symbol[idx3][:100], name='Correlated PC3')._repr_html_()+'</td><td>'+
     ToppGeneEnrichement(symbol[idx3][-100:], name='Anti-Corr PC3')._repr_html_()+'</td></tr><tr><td>'+
     ToppGeneEnrichement(symbol[idx4][:100], name='Correlated PC4')._repr_html_()+'</td><td>'+
     ToppGeneEnrichement(symbol[idx4][-100:], name='Anti-Corr PC4')._repr_html_()+'</td></tr></table>')
# Out:
# <table><tr><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SEMG1 CCDC172 TCL1B AF165138.7 AHSP DPEP3 HHLA1 RP11-297M9.1 DAZL CHST4 IDO1 NKX1-2 NCR1 PRDM14 HTR1A LGALS12 UTF1 HES3 UCMA SIT1 CCL26 C12orf56 TNFSF11 MT1H ZSCAN10 C1orf94 IFI30 MT1M LCK P2RX5 SCGB3A2 CR1L TRIM54 KLRG2 KLKB1 VRTN KCNG3 FAM71F1 CUZD1 GLIPR1L1 GDF3 GHRHR NANOG TNFRSF8 AC010646.3 AC018867.2 AP001350.1 POU5F1 SPIB TDGF1 MT1G ACOXL TMPRSS11E TNFRSF11A PVALB MAGEB17 DPPA2 PLSCR2 HTR7 CRYGD ZNF560 LECT1 AGXT2L1 KLK13 NMRK2 PSMB9 USP44 HLA-DRA SNCB HRASLS5 GLB1L3 CXCL5 MB21D1 HTR3A A2ML1 ACSBG1 GYPB FOXH1 ZNF208 SRY NRN1L COX7A1 KLHDC7A CD70 TIMP4 PDE6G TRPA1 L1TD1 EMX1 GRM4 CD48 PPP1R1B GRID2 LHFPL4 GPR114 AKR1C3 MGC4771 C16orf89 M1AP CALCR">
#         <input type="submit" value="Correlated PC2">
#         </form></td><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="MAB21L2 HOXB1 APOC4 ADCYAP1 LHX9 TBX2 FOXF2 CDX2 HOXA7 ALB TYRP1 PITX1 MEP1A CSF3R SLC18A3 WNT10A HOXA1 APOH SEBOX HOXA10 APOA2 SST C15orf48 SULT1E1 ART4 TBX4 IGF2 TBX5 HOPX DLX1 HOXA9 MMP1 PLG IGFL2 BARHL2 HAND1 WNT1 ERP27 HOXB9 SCRG1 C5orf46 SRPX2 OLR1 HBE1 SLPI COL3A1 HOXB7 HOXD4 APOA4 UBD HOXD8 SERPINB2 HOXB6 HOXA2 HOXB3 PLN HOXB4 HOXA5 FOXF1 WISP1 WNT6 CFI TECRL HMGCS2 KRT23 FAP RGS13 LIPC NNMT WNT2 HOXC8 TM4SF4 HOXC10 HOXA3 ANXA8L2 ESM1 HOXC6 HOXC4 HOXB2 HOXB8 FGA HAND2 HOXA4 FGG SERPINA1 SLN LUM HOXC5 S100A9 PRHOXNB HOXC9 FABP1 KRTAP2-3 VGLL1 HOXB5 DCN MGP FGB APOC3 TTR">
#         <input type="submit" value="Anti-Corr PC2">
#         </form></td></tr><tr><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="S100B PLA2G2A HES3 AHSP HTR1A OLIG3 FXYD3 UCMA KLK8 PSMB9 TMEM176A UBD G0S2 GHRHR SYT5 CCDC172 SOX1 ATOH1 BTBD17 HLA-DRA C12orf68 P2RX3 PVALB RP11-571M6.6 SST FOXB1 DNAJC12 FAM163A FAIM2 ASGR2 LRRC55 NPPC TMEFF2 FAM212A CEND1 HES5 TRIM29 RAB33A AC012360.2 DAZL EBF1 CYP1A1 AMBP PHYHIP PPP1R17 SLC18A3 STMN4 NSG2 CRYAB FZD10 TDO2 NTRK3 HOXA1 TCL1B PHACTR3 CPLX2 WNT10A APLN FAP ELAVL3 SCRG1 SIT1 SOST UTF1 DNER PAH TMEM151A TRIM22 CA4 SLC38A4 GRIA1 MT1M WIF1 WNT10B PALM2-AKAP2 SCN4B PTPRO C1QL4 C5orf38 TMEM176B CAMKV GDPD2 FAM19A4 GRIA4 APOH RHBDL3 LECT1 TMEM173 ATP1A3 SNCG NPY WNT8B RAMP1 OLFM3 POU3F1 MMP28 RP11-297M9.1 HOXA7 NRXN2 ORM1">
#         <input type="submit" value="Correlated PC3">
#         </form></td><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="PCDH10 PLXNA2 ST8SIA4 CCDC81 IHH ARHGAP40 EPSTI1 CCKBR SRY FGF8 TRDN EIF1AY MYL7 MYCT1 AMHR2 PLCE1 IFLTD1 SAMD11 APOL3 TMEM200B CXCR4 SEMA3E SHOX2 ZAP70 MYL4 CST1 TRH FOXC1 CNGA4 TBX3 HNF1B HBE1 FGA HAS2 SLC5A9 BDKRB1 PRDM1 MGC4771 CALCR DLX5 LHX1 NODAL GATA3 IL18R1 LGR5 MOBP LGALS12 HHEX TRPM2 VWF PITX2 APOA2 PAICS MIXL1 MAGEB17 SLC40A1 RTN4RL1 CYP26A1 CD48 PPAPDC1A PLCXD3 TRPA1 GSTA1 GREM2 NR0B1 CST2 FOXA2 SLITRK2 NCR1 GSTA2 FBXL8 HP APOA4 DIO3 TBX20 NPPB LEFTY1 SYNE3 GATA6 RFPL2 LEFTY2 GATA4 MNX1 CSF3R HNF4A GRP FOXQ1 WT1 EOMES RXRG OLR1 CER1 GSC FGF17 SOX18 PLSCR2 SOX17 PRSS1 LYPD2 GYPB">
#         <input type="submit" value="Anti-Corr PC3">
#         </form></td></tr><tr><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="KLK13 TIMP4 GSTA2 MGAT4C ORM1 APOC3 HP HOXB7 GDF3 ASGR2 HOXB8 HOXB2 HOXC6 TFF3 FGG GJB1 SEMG1 APOA2 UPK3A FGA TBX5 NKX1-2 IFI30 HOXA9 HSPB7 HOXB4 PLN APOA4 HOXA10 COL8A2 PRHOXNB GLI1 FGB ATOH1 SLPI HHLA1 C5orf46 IHH GHRHR CLIC3 HOXC10 UCMA REN CCL26 HOXB6 BDKRB1 CCDC172 TBX4 TMPRSS11E LIPC HOXC8 AHSG HTR3A WT1 RGS13 HOXB5 BCL11A MT1M SPINK1 KRT6A HOXB1 HOXC9 HOXC5 HOXA5 TECRL HGD P2RX5 C19orf33 MGP IL18R1 PENK HOXA4 PMEPA1 HOXB9 AMBP MEP1A KRT5 HTR1A LAMC3 FAM3B HOXB3 CXCL1 NPPC C1orf94 CST1 RP11-404P21.8 HOXC4 SERPINA1 CYP24A1 CARD16 SFRP5 IGFL2 SULT1E1 HOXA7 HOXD3 CDX2 AL807752.1 RBP4 TM4SF4 SLC25A48">
#         <input type="submit" value="Correlated PC4">
#         </form></td><td><form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="SKIDA1 NRN1 LRP2 POU4F1 SULF1 DMRTA1 FEZF1 TSHZ2 STOX1 MMRN1 ZFHX4 HOPX CNTN6 WNT7B CCDC177 DPEP3 RBFOX1 CMTM5 MYO3B KLHL14 TPBG MAB21L2 LHX9 PLCXD3 PRTG WLS CCNO IRS4 SP8 HES4 ILDR2 C8orf4 DLL1 NRIP3 KCNK10 HOXA1 GREB1L WNT3A C6orf118 ZNF503 NRG2 PGM5 WNT2B NDUFB8 TFAP2B SIX3 FAP RP6-24A23.6 HSD17B2 MUSTN1 TFRC FOXC2 PEG3 DRD4 SCUBE2 PVALB LGI1 OLFM3 MEOX1 HMGCS2 NR2F1 GDF7 ADCYAP1 WNT8B OTX1 SOX1 NR2F2 C1orf213 RTN4RL1 PAX3 WNT6 AOAH LYPD2 TRH CCK DLX5 KRT23 MGC4771 BARHL2 PAICS LHX5 ARHGAP15 BCMO1 CLVS1 RAX ERP27 KCNJ13 LMX1A PAX6 HES5 ZBTB16 GRP BARHL1 NOS2 WNT1 EMX2 VGLL1 FEZF2 LIM2 GALP">
#         <input type="submit" value="Anti-Corr PC4">
#         </form></td></tr></table>

# %% [markdown]
# ###Methylation
# The methylation data has arelady been quantile normalized.  (See the provenance of the [syn2233188](https://www.synapse.org/#!Synapse:syn2233188)).  I will perform a PCA anyway to look for issues with the data by first extracting the top 50th percentile variable probes.

# %%
#The methylation data has arelady been quantile normalized will perform 
#scaling before performing PCA and reduce the dataset (for speed) by
var = methyl.var(axis=1)
d = methyl[var>np.percentile(var, 50)]
d = MicroArray.scale(d)
u,s,vt=MicroArray.QaD_SVD(d, methyl_meta, plotEigengenes=False)

# %% [markdown]
# **Observations:** The PCs correspond well with differentiation state.  Scaling by features (not shown) shows that the 4th pc corresponds to Gender.

# %% [markdown]
# #Save normalized samples to Synapse

# %%
code = synapseclient.File('C4_qc_filtering_normalization.ipynb', parentId='syn2246673')
code = syn.store(code)

logExprData.to_csv('rnaseq_norm.tsv', sep='\t')
file = synapseclient.File('rnaseq_norm.tsv', parentId='syn1773109', name='Normalized mRNACalls')
rnaID = syn.store(file, used=[BIOMART_ANNOT_ID, EXPR_ID, EXPR_META_ID], 
                  executed=[code],
                  activityName='QC and Filtering')

#mirseq_norm.to_csv('mirseq_norm.tsv', sep='\t')
#mirID = syn.store(synapseclient.File('mirseq_norm.tsv', parentId='syn1773109', name='Normalized miRNACalls'))
# Out:
# .
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# .
# ,
# !
# !
# !
# !
# !
# Upload completed in 21 seconds.

# %% [markdown]
# #Follow-up analysis
# is available in the notebook: C4-differential_analysis.ipynb
