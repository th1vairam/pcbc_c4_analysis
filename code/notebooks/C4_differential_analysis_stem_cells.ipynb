# %%
import synapseclient
import numpy as np
import pandas as pd
import scipy.stats as stats
#Regression 
import statsmodels.formula.api as sm
import statsmodels.stats.multitest as smm
from statsmodels.regression.mixed_linear_model import MixedLM
#Analysis tools
from collections import Counter as count
import hierarchical_clustering as clust
import MicroArray
from toppGenePost import ToppGeneEnrichement
#Other packages
import IPython.display as display
import string

EXPR_NORM_ID = 'syn2701943'
EXPR_META_ID = 'syn2278178'
METH_ID = 'syn2233188'
METH_META_ID = 'syn2677043'
MIRSEQ_NORM_ID = 'syn2701942'
MIRSEQ_META_ID = 'syn2278179'
pd.set_option('max_columns', 200)
syn = synapseclient.login()
# Out:
# Welcome, Larsson Omberg!

# %% [markdown]
# #Download and annotate data
# 1. Downloads expression/miRNA-Seq/methylation data from Synapse
# 2. Gets annotations from metadata in Synapse
# 3. Make sure the metadata matches up with samples

# %%
mirseq = pd.read_csv(syn.get(MIRSEQ_NORM_ID).path, sep='\t', index_col=0)
mirseq_meta = pd.read_csv(syn.get(MIRSEQ_META_ID).path, sep='\t',index_col=0)
mirseq_meta = mirseq_meta.ix[mirseq.columns,:]
print 'Mirseq Data Size:', mirseq.shape, mirseq_meta.shape
rnaseq = pd.read_csv(syn.get(EXPR_NORM_ID).path, sep='\t', index_col=[0,1,2])
rnaseq_meta = pd.read_csv(syn.get(EXPR_META_ID).path, sep='\t',index_col=0)
rnaseq_meta = rnaseq_meta.ix[rnaseq.columns,:]
print 'RNA-Seq Data Size:', rnaseq.shape, rnaseq_meta.shape
methyl = pd.read_csv(syn.get(METH_ID).path, sep='\t', index_col=0)
methyl_meta = pd.read_csv(syn.get(METH_META_ID).path, sep='\t',index_col=0)
methyl_meta = methyl_meta.ix[methyl.columns,:]
print 'Methylation Data Size:', methyl.shape, methyl_meta.shape
# Out:
# Mirseq Data Size: (1302, 127) (127, 39)
# RNA-Seq Data Size:
#  (13242, 217) (217, 37)
# Methylation Data Size:
#  (485512, 92) (92, 37)

# %% [markdown]
# ###Prune and rename metadata

# %%
toRemove = ['Related C4 ID comment', 'Sage verified RNA-Seq', 'Sage verified']
mirseq_meta.drop(toRemove,1, inplace=True)
rnaseq_meta.drop(toRemove,1, inplace=True)
rnaseq_meta.drop(['Bad Lines'],1, inplace=True)
methyl_meta.drop(toRemove,1, inplace=True)
mirseq_meta.rename(columns={'High Confidence Donor ID (HCDID)':'Donor id'}, inplace=True)
rnaseq_meta.rename(columns={'High Confidence Donor ID (HCDID)':'Donor id'}, inplace=True)
methyl_meta.rename(columns={'High Confidence Donor ID (HCDID)':'Donor id'}, inplace=True)
methyl_meta['Array'] = methyl_meta['Array'].astype('str')

# %% [markdown]
# ###Filter down to the stem cell only samples

# %%
mirseq = mirseq.ix[:,mirseq_meta.CellDiffState=='SC']
mirseq_meta = mirseq_meta.ix[mirseq_meta.CellDiffState=='SC',:]
print 'Mirseq Data Size:', mirseq.shape, mirseq_meta.shape
rnaseq = rnaseq.ix[:, rnaseq_meta.CellType=='SC']
rnaseq_meta = rnaseq_meta.ix[rnaseq_meta.CellType=='SC',:]
print 'RNA-seq Data Size:', rnaseq.shape, rnaseq_meta.shape
methyl = methyl.ix[:,methyl_meta['Diffname short']=='SC']
methyl_meta = methyl_meta.ix[methyl_meta['Diffname short']=='SC', :]
print 'Methylation Data Size:', methyl.shape, methyl_meta.shape
# Out:
# Mirseq Data Size: (1302, 27) (27, 36)
# RNA-seq Data Size: (13242, 68) (68, 33)
# Methylation Data Size:
#  (485512, 44) (44, 34)

# %% [markdown]
# #Make PCA plots

# %% [markdown]
# ##RNA-Seq

# %%
u,s,vt = MicroArray.QaD_SVD(MicroArray.scale(rnaseq.T).T, rnaseq_meta.drop('CellLine', 1), plotEigengenes=False)

# %% [markdown]
# ##Micro RNA-Seq

# %%
u,s,vt = MicroArray.QaD_SVD(MicroArray.scale(mirseq.T).T, mirseq_meta, plotEigengenes=False)

# %% [markdown]
# ##Methylation Arrays

# %%
u,s,vt = MicroArray.QaD_SVD(MicroArray.scale(methyl.T).T, methyl_meta, plotEigengenes=False)

# %% [markdown]
# #Identify features correlated with reprogramming and cell of origin
#
# As we have multiple samples derived from the same individual we will used a mixed Effect Linear model where we treat donor and gender as radom effects.  In effect we are fitting the following model for each gene/feature $i$.
# $$Y_{i} = X\cdot\beta + Z\cdot\gamma + epsilon$$
#
# where $X$ represent for example the  reprogramming vector or cell of origin an $Z$ is the matrix of random effects components.

# %%
def lmemodel(data, metadata, 
             fixedEffects = ['Tissue of Origin'],
             randomEffects=['High Confidence Donor ID (HCDID)']):
    """Performs a mixed effect linear model"""
    df = metadata[fixedEffects].copy()
    df = pd.concat([df, metadata[randomEffects]], axis=1 )
    #Change the parameters to be compatible with patsy formulas
    fixedEffects = [c.translate(string.maketrans(' ()', '___')) for c in fixedEffects]
    randomEffects = [c.translate(string.maketrans(' ()', '___')) for c in randomEffects]
    df.columns = [c.translate(string.maketrans(' ()', '___')) for c in df.columns]

    model_string = 'gene ~ '+' + '.join(fixedEffects)
    results = []
    for i in range(data.shape[0]):
        #Add the dependent variable to the dataframe
        df['gene'] = data.irow(i)
        #################
        df['High_Confidence_Donor_ID__HCDID_'] = stats.binom.rvs(1, .4, size=69)
        print df.shape, model_string
        return df
        df = df.dropna()
        print df.shape
        #################
        #compute new model
        mod = MixedLM.from_formula(model_string, df, groups = df[randomEffects])
        return mod
        #df.boxplot(by=fixedEffects)
        #mod = sm.ols(model_fit, df)
        #results.append(mod.fit())
    return results



#pd.crosstab(rnaseq_meta['Tissue of Origin'], rnaseq_meta['High Confidence Donor ID (HCDID)'])
res = lmemodel(rnaseq.ix[:1,:], rnaseq_meta)
#Find the significant genes based on f-test
#pvals = np.asarray([r.f_pvalue for r in res])
#print sum(pvals*len(pvals)<0.01), pvals

#Plot some of the genes
#pd.concat( [mirseq.ix[:1,:].T, mirseq_meta[['Tissue of Origin', 
#                                            'Gender', 
#                                            'High Confidence Donor ID (HCDID)' ]]], axis=1).boxplot(by=['Tissue of Origin', 
#                                                                                                        'Gender'], rot=90)
# Out:
# (69, 3) gene ~ Tissue_of_Origin

# %%
#res.fit()
pd.crosstab(res.Tissue_of_Origin, res.High_Confidence_Donor_ID__HCDID_)
# Out:
# High_Confidence_Donor_ID__HCDID_   0  1
# Tissue_of_Origin
# UNK                                3  1
# amniotic fluid                     1  1
# blastocyst                         6  7
# bone marrow                        4  2
# foreskin                           9  5
# skin                              11  7
# umbilical cord blood               7  5
#
# [7 rows x 2 columns]

# %%
def residualmodel(data, metadata, 
          parameters=['Gender', 'High Confidence Donor ID (HCDID)', 
                      'Tissue of Origin']):
    """Performs a lineal mode on all parameters except last one then uses the residuals of this model
    to fit a model on the last parameters"""
    df = metadata[parameters].copy()
    #Change the parameters to be compatible with patsy formulas
    df.columns = [c.translate(string.maketrans(' ()', '___')) for c in df.columns]
    parameters = list(df.columns)
    norm_params = parameters[:-1]
    fit_params = parameters[-1]
    model_norm = 'gene ~ '+' + '.join(norm_params)
    model_fit = 'gene ~ '+ fit_params
    results = []
    for i in range(data.shape[0]):
        df['gene'] = data.irow(i)
        #Fit model for nuiscance parameters
        mod = sm.ols(model_norm, df)
        #Find residuals and compute new model
        df['gene'] = mod.fit().resid
        df.boxplot(by=parameters[-1])
        mod = sm.ols(model_fit, df)
        results.append(mod.fit())
    return results

def model(data, metadata, parameter='Gender'):
    """Performs a lineal mode on all parameters except last one then uses the residuals of this model
    to fit a model on the last parameters"""
    df = metadata[[parameter]].copy()
    #Change the parameters to be compatible with patsy formulas
    df.columns = [parameter.translate(string.maketrans(' ()', '___'))]
    parameter = df.columns[0]
    model_fit = 'gene ~ '+ parameter
    results = []
    for i in range(data.shape[0]):
        df['gene'] = data.irow(i)
        #Fit model for nuiscance parameters
        mod = sm.ols(model_fit, df)
        results.append(mod.fit())
    return results

resOrigin = model(mirseq.ix[:,:], mirseq_meta, parameter='Tissue of Origin')
resGender = model(mirseq.ix[:,:], mirseq_meta, parameter='Gender')
resReprog = model(mirseq.ix[:,:], mirseq_meta, parameter='Reprogramming Vector Type')
resCellType = model(mirseq.ix[:,:], mirseq_meta, parameter='Cell Line Type')
pvals = pd.DataFrame({'Tissue_of_Origin':[r.f_pvalue for r in resOrigin],
                      'Gender' :[r.f_pvalue for r in resGender],
                      'Reprogramming_Vecor': [r.f_pvalue for r in resReprog],
                      'Cell Line Type': [r.f_pvalue for r in resCellType]},
                     index = mirseq.index)

# %%
pvals.sort(pvals.columns[3])
#q=pd.concat([mirseq_meta, mirseq.ix[pvals[4:6].index,:].T], axis=1)
#q.boxplot(by='Reprogramming Vector Type')
#mirseq_meta[mirseq_meta['Reprogramming Vector Type']=='lentivirus']
#pd.crosstab(mirseq_meta['Reprogramming Vector Type'], mirseq_meta['High Confidence Donor ID (HCDID)'])
# Out:
#                                 Cell Line Type    Gender  Reprogramming_Vecor  \
# mir
# hsa-mir-28,hsa-miR-28-5p              0.176886  0.987216             0.468541
# hsa-mir-138-1,hsa-miR-138-5p          0.079107  0.206014             0.009642
# hsa-mir-431,hsa-miR-431-5p            0.913355  0.293638             0.655095
# hsa-mir-138-2,hsa-miR-138-5p          0.084640  0.195552             0.009589
# hsa-mir-335,hsa-miR-335-5p            0.180695  0.226195             0.750684
# hsa-mir-130b,hsa-miR-130b-3p          0.230361  0.453957             0.195107
# hsa-mir-758,hsa-miR-758-3p            0.829220  0.590378             0.561209
# hsa-mir-30d,hsa-miR-30d-5p              0.035737
# hsa-mir-128-2,hsa-miR-128-3p            0.036233
# hsa-mir-378a,hsa-miR-378a-3p            0.037805
# hsa-mir-889,hsa-miR-889-3p              0.038532
# hsa-mir-302c,hsa-miR-302c-3p            0.038560
# hsa-mir-30e,hsa-miR-30e-3p              0.039471
# hsa-mir-15b,hsa-miR-15b-5p              0.039962
# hsa-mir-25,hsa-miR-25-3p                0.041708
# hsa-mir-130b,hsa-miR-130b-5p            0.045281
# hsa-mir-409,hsa-miR-409-3p              0.049083
# hsa-mir-941-1,hsa-miR-941               0.049425
# hsa-mir-941-4,hsa-miR-941               0.049425
# hsa-mir-941-2,hsa-miR-941               0.049425
# hsa-mir-941-3,hsa-miR-941               0.049425
# hsa-mir-299,hsa-miR-299-3p              0.049988
# hsa-mir-141,hsa-miR-141-5p              0.051766
# hsa-mir-30a,hsa-miR-30a-5p              0.052967
# hsa-mir-409,hsa-miR-409-5p              0.055897
# hsa-mir-93,hsa-miR-93-5p                0.058078
# hsa-mir-520f,hsa-miR-520f-3p            0.058413
# hsa-mir-423,hsa-miR-423-5p              0.061199
#                                              ...
#
# [1302 rows x 4 columns]

# %%
mirseq_meta
# Out:
#                       CellDiffState    QC            Exclude C4 Cell Line ID  \
# H9.112.5.10                      SC  PASS  replicate-exclude              H9
# H9.112.5.9                       SC  PASS                NaN              H9
# IPS18-4_1.112.5.11               SC  PASS                NaN           IPS18
# IPS18-4_2.112.5.12               SC  PASS  replicate-exclude           IPS18
# SC11-004.574.1.45                SC  PASS                NaN        SC11-004
# SC11-008.436.1.27                SC  PASS                NaN        SC11-008
# SC11-009.436.1.34                SC  PASS                NaN        SC11-009
# SC11-010.436.1.35                SC  PASS                NaN        SC11-010
# SC11-012.436.1.26                SC  PASS                NaN        SC11-012
# SC11-013.436.1.25                SC  PASS                NaN        SC11-013
# SC11-014.436.1.32                SC  PASS                NaN        SC11-014
# SC11-014BULK.574.1.26            SC  PASS                NaN        SC11-014
# SC11-015.574.1.46                SC  PASS                NaN        SC11-015
# SC11-016.574.1.47                SC  PASS                NaN        SC11-016
# SC11-017.574.1.48                SC  PASS                NaN        SC11-017
# SC11-017A.146.6.9                SC  PASS                NaN        SC11-017
# SC11-018A.146.6.10               SC  PASS                NaN        SC11-018
# SC12-005B.146.6.12               SC  PASS                NaN        SC12-005
# SC12-006A.146.6.21               SC  PASS                NaN        SC12-006
# SC12-024.436.1.33                SC  PASS                NaN        SC12-024
# SC12-038.386.2.13                SC  PASS                NaN        SC12-038
# SC12-039.436.1.31                SC  PASS                NaN        SC12-039
# SC13-043.386.2.14                SC  PASS                NaN        SC13-043
# SC13-044.239.6.32                SC  PASS                NaN        SC13-044
# SC13-045.239.6.33                SC  PASS                NaN        SC13-045
# SC13-049.239.7.25                SC  PASS                NaN        SC13-049
# SC14-066.574.1.34                SC  PASS                NaN        SC14-066
#
#                        PCBC Cell Line Name Host species Originating Lab ID  \
# H9.112.5.10                            NaN        human                NaN
# H9.112.5.9                             NaN        human                NaN
# IPS18-4_1.112.5.11                     NaN        human                NaN
#
#                       Cell Type of Origin Cell Line of Origin  \
# H9.112.5.10               inner cell mass                 NaN
# H9.112.5.9                inner cell mass                 NaN
# IPS18-4_1.112.5.11            CD34+ cells                 NaN
# IPS18-4_2.112.5.12            CD34+ cells                 NaN
# SC11-004.574.1.45              fibroblast                 NaN
# SC11-008.436.1.27             CD34+ cells                 NaN
# SC11-009.436.1.34             CD34+ cells                 NaN
# SC11-010.436.1.35             CD34+ cells                 NaN
# SC11-012.436.1.26             CD34+ cells                 NaN
# SC11-013.436.1.25             CD34+ cells                 NaN
# SC11-014.436.1.32         inner cell mass                 NaN
# SC11-014BULK.574.1.26     inner cell mass                 NaN
# SC11-015.574.1.46         inner cell mass                 NaN
# SC11-016.574.1.47              fibroblast                 UNK
# SC11-017.574.1.48              fibroblast                 UNK
# SC11-017A.146.6.9              fibroblast                 UNK
# SC11-018A.146.6.10             fibroblast                 UNK
# SC12-005B.146.6.12             fibroblast                 UNK
# SC12-006A.146.6.21             fibroblast                 UNK
# SC12-024.436.1.33              fibroblast                 UNK
# SC12-038.386.2.13         inner cell mass                 NaN
# SC12-039.436.1.31         inner cell mass                 NaN
# SC13-043.386.2.14             mononuclear                 NaN
# SC13-044.239.6.32             mononuclear                 NaN
# SC13-045.239.6.33             mononuclear                 NaN
# SC13-049.239.7.25              fibroblast                 NaN
# SC14-066.574.1.34         inner cell mass                 NaN
#
#                            Tissue of Origin Reprogramming Vector Type  \
# H9.112.5.10                      blastocyst                       NaN
# H9.112.5.9                       blastocyst                       NaN
# IPS18-4_1.112.5.11              bone marrow                lentivirus
# IPS18-4_2.112.5.12              bone marrow                lentivirus
# SC11-004.574.1.45                      skin                lentivirus
# SC11-008.436.1.27      umbilical cord blood                   plasmid
# SC11-009.436.1.34      umbilical cord blood                   plasmid
# SC11-010.436.1.35      umbilical cord blood                   plasmid
# SC11-012.436.1.26      umbilical cord blood                   plasmid
# SC11-013.436.1.25      umbilical cord blood                   plasmid
# SC11-014.436.1.32                blastocyst                       NaN
# SC11-014BULK.574.1.26            blastocyst                       NaN
# SC11-015.574.1.46                blastocyst                       NaN
# SC11-016.574.1.47                  foreskin                   plasmid
# SC11-017.574.1.48                  foreskin                   plasmid
# SC11-017A.146.6.9                  foreskin                   plasmid
# SC11-018A.146.6.10                 foreskin                   plasmid
# SC12-005B.146.6.12                     skin                   plasmid
# SC12-006A.146.6.21                     skin                   plasmid
# SC12-024.436.1.33                       UNK                retrovirus
# SC12-038.386.2.13                blastocyst                       NaN
# SC12-039.436.1.31                blastocyst                       NaN
# SC13-043.386.2.14               bone marrow                   plasmid
# SC13-044.239.6.32               bone marrow                   plasmid
# SC13-045.239.6.33      umbilical cord blood                   plasmid
# SC13-049.239.7.25                      skin                retrovirus
# SC14-066.574.1.34                blastocyst                       NaN
#
#                       Reprogramming Gene Combination Culture Conditions  \
# H9.112.5.10                                      NaN                NaN
# H9.112.5.9                                       NaN                NaN
# IPS18-4_1.112.5.11                              OSKM                UNK
# IPS18-4_2.112.5.12                              OSKM                UNK
# SC11-004.574.1.45                               OSKM        Cre-excised
# SC11-008.436.1.27                           OSKM-NLT     Stromal primed
# SC14-066.574.1.34                                         not examined
#
#                                                          donor cell link  \
# H9.112.5.10                                                          NaN
# H9.112.5.9                                                           NaN
# IPS18-4_1.112.5.11                                                   NaN
# IPS18-4_2.112.5.12                                                   NaN
# SC11-004.574.1.45      http://ccr.coriell.org/Sections/Search/Sample_...
# SC11-008.436.1.27                                                    NaN
# SC11-009.436.1.34                                                    NaN
# SC11-010.436.1.35                                                    NaN
# SC11-012.436.1.26                                                    NaN
# SC11-013.436.1.25                                                    NaN
# SC11-014.436.1.32                                                    NaN
# SC11-014BULK.574.1.26                                                NaN
# SC11-015.574.1.46                                                    NaN
# SC11-016.574.1.47         http://www.atcc.org/products/all/CRL-2097.aspx
# SC11-017.574.1.48         http://www.atcc.org/products/all/CRL-2097.aspx
# SC11-017A.146.6.9         http://www.atcc.org/products/all/CRL-2097.aspx
# SC11-018A.146.6.10        http://www.atcc.org/products/all/CRL-2097.aspx
# SC12-005B.146.6.12                                                   NaN
# SC12-006A.146.6.21                                                   NaN
# SC12-024.436.1.33                                                    NaN
# SC12-038.386.2.13                                                    NaN
# SC12-039.436.1.31                                                    NaN
# SC13-043.386.2.14                                                    NaN
# SC13-044.239.6.32                                                    NaN
# SC13-045.239.6.33                                                    NaN
# SC13-049.239.7.25                                                    NaN
# SC14-066.574.1.34                                                    NaN
#
#                       High Confidence Donor ID (HCDID)  \
# H9.112.5.10                                        NaN
# H9.112.5.9                                         NaN
# IPS18-4_1.112.5.11                                 NaN
# IPS18-4_2.112.5.12                                 NaN
# SC11-004.574.1.45                                 D001
# SC11-008.436.1.27                                 D003
# SC11-009.436.1.34                                 D003
# SC11-010.436.1.35                                 D003
# SC11-012.436.1.26                                 D012
# SC11-013.436.1.25                                 D013
# SC11-014.436.1.32                                 D014
# SC11-014BULK.574.1.26                             D014
# SC11-015.574.1.46                                 D015
# SC11-016.574.1.47                                 D004
# SC11-017.574.1.48                                 D004
# SC11-017A.146.6.9                                 D004
# SC11-018A.146.6.10                                D004
# SC12-005B.146.6.12                               D005A
# SC12-006A.146.6.21                                D016
# SC12-024.436.1.33                                 D007
# SC12-038.386.2.13                                 D018
# SC12-039.436.1.31                                 D019
# SC13-043.386.2.14                                 D020
# SC13-044.239.6.32                                 D021
# SC13-045.239.6.33                                 D022
# SC13-049.239.7.25                                 D008
# SC14-066.574.1.34                                  NaN
#
#                       GroupLevel1 DifferentiationState  \
# H9.112.5.10                                   StemCell
# H9.112.5.9                                    StemCell
# IPS18-4_1.112.5.11                            StemCell
# IPS18-4_2.112.5.12                            StemCell
# SC11-004.574.1.45                             StemCell
# SC11-008.436.1.27                             StemCell
# SC11-009.436.1.34                             StemCell
# SC11-010.436.1.35                             StemCell
# SC11-012.436.1.26                             StemCell
# SC11-013.436.1.25                             StemCell
# SC11-014.436.1.32                             StemCell
# SC11-014BULK.574.1.26                         StemCell
# SC11-015.574.1.46                             StemCell
# SC11-016.574.1.47                             StemCell
# SC11-017.574.1.48                             StemCell
# SC11-017A.146.6.9                             StemCell
# SC11-018A.146.6.10                            StemCell
# SC12-005B.146.6.12                            StemCell
# IPS18-4_2.112.5.12                           SC-HD             SC  Best-SC
# SC11-004.574.1.45                            SC-HD             SC      NaN
# SC11-008.436.1.27                            SC-HD             SC      NaN
# SC11-009.436.1.34                            SC-HD             SC      NaN
# SC11-010.436.1.35                            SC-HD             SC      NaN
# SC11-012.436.1.26                            SC-HD             SC      NaN
# SC11-013.436.1.25                            SC-HD             SC      NaN
# SC11-014.436.1.32                            SC-HD             SC      NaN
# SC11-014BULK.574.1.26                        SC-HD             SC      NaN
# SC11-015.574.1.46                            SC-HD             SC      NaN
# SC11-016.574.1.47                            SC-HD             SC      NaN
# SC11-017.574.1.48                            SC-HD             SC      NaN
# SC11-017A.146.6.9                            SC-HD             SC      NaN
# SC11-018A.146.6.10                           SC-HD             SC  Best-SC
# SC12-005B.146.6.12                           SC-HD             SC  Best-SC
# SC12-006A.146.6.21                           SC-HD             SC  Best-SC
# SC12-024.436.1.33                            SC-HD             SC      NaN
# SC12-038.386.2.13                            SC-HD             SC  Best-SC
# SC12-039.436.1.31                            SC-HD             SC      NaN
# SC13-043.386.2.14                            SC-HD             SC  Best-SC
# SC13-044.239.6.32                            SC-HD             SC  Best-SC
# SC13-045.239.6.33                            SC-HD             SC  Best-SC
# SC13-049.239.7.25                            SC-HD             SC  Best-SC
# SC14-066.574.1.34                            SC-HD             SC      NaN
#
# [27 rows x 38 columns]

# %% [markdown]
# ##Cell of origin and Induction gene analysis

# %%
def runModels(data):
    #Put the data into temporary datastructure
    df = data.T
    #I have to temporarily rename the genes to work with Patsy formulas
    df.columns = ['gene_%i' %i for i in range(len(df.columns))] 
    df['origcell'] = metadata['origcell']
    df['inductiongenes'] = metadata['inductiongenes']

    #Exclude HESCs
    #idx = metadata.linetype !='hESC'
    #df = df.ix[idx,:]
    
    def model(geneName):
        mod1 = sm.ols('%s ~ origcell' %geneName, df)
        mod2 = sm.ols('%s ~ inductiongenes' %geneName, df)
        return mod1.fit().f_pvalue, mod2.fit().f_pvalue
    
    #from multiprocessing import Pool
    #pool = Pool()
    pvals = map(model, df.columns[:-2])
    #pool.join()
    pvals = np.asarray(pvals)
    
    models = pd.DataFrame(symbol.copy())
    models['origcell']=pvals[:,0]
    models['inductiongenes']=pvals[:,1]
    return models

normPvals = runModels(logExprDataNorm)
#origPvals = runModels(logExprData)

# %% [raw]
# ##Store the pvalues to synapse
# models = pd.DataFrame(symbol.copy())
# models['coi_fdr_corrected_p (normalized data)'] = smm.multipletests(normPvals.origcell, alpha=0.05, method='fdr_bh')[1]
# models['genes_fdr_corrected_p (normalized data)'] = smm.multipletests(normPvals.inductiongenes, alpha=0.05, method='fdr_bh')[1]
#
# models['coi_fdr_corrected_p (uncorrected data)'] = smm.multipletests(origPvals.origcell, alpha=0.05, method='fdr_bh')[1]
# models['genes_fdr_corrected_p (uncorrected data)'] = smm.multipletests(origPvals.inductiongenes, alpha=0.05, method='fdr_bh')[1]
#
# models.to_csv('model_corrected_pvalues_for_shane.csv')
#
# code = syn.store(synapseclient.File('C4_qc_and_linear_models.ipynb', parent='syn1774100'))
# ent = synapseclient.File('model_corrected_pvalues_for_shane.csv', parent='syn2332184')
# ent = syn.store(ent, used=[EXPR_ID, METADATA_ID], executed=code)
# syn.onweb(ent)

# %% [markdown]
# ###Compare these models to the genelists found by Nathan

# %%
import matplotlib_venn

#Determine significant genes using Benjamini-Hochberg FDR correction
def filterPvals2GeneSymbols(pvals):
    pval_pass = smm.multipletests(pvals, alpha=0.05, method='fdr_bh')[0]
    return symbol[pval_pass]

#coi_signficant_logExprData= filterPvals2GeneSymbols(origPvals.origcell)
coi_signficant_logExprDataNorm= filterPvals2GeneSymbols(normPvals.origcell)
nathan_coi=pd.DataFrame.from_csv('COI-GeneExpression-signatures.csv')
matplotlib_venn.venn2([set(coi_signficant_logExprDataNorm),  #set(coi_signficant_logExprData), 
                       set(nathan_coi.index)], 
                       set_labels=['normalized', 'AltAnalyze']) #'unormalized', 
pylab.title('Significant Gene counts for COI')

display.display_html(ToppGeneEnrichement(coi_signficant_logExprDataNorm, name='COI'))
print set(nathan_coi.index).intersection(set(coi_signficant_logExprDataNorm))
# Out:
# <form action="https://toppgene.cchmc.org/CheckInput.action" method="post" target="_blank">
#         <input type="hidden" name="query" value="TOPPFUN">
#         <input type="hidden" id="type" name="type" value="HGNC">
#         <input type="hidden" name="training_set" id="training_set" value="GCLC CFTR SLC4A1 DHX33 TMEM132A ZNF263 TNFRSF12A PNPLA4 NOS2 RPUSD1 TSR3 CDKL5 RPS20 KAL1 ZBTB32 KDM5D STMN4 SRCIN1 HGF CPS1 SNAPC1 PQLC2 CTNS ZIC2 OFD1 GPM6B CTPS2 KITLG PER3 FAM160A2 MSMO1 TTC17 SZRD1 GYG2 SLC2A3 GUCY1B3 ZNF112 EIF4B SPHK2 ST3GAL6 PMS1 OAT NDUFB4 CTNNA2 DDX3Y NEO1 TFE3 IFT80 SDK2 GAL FUNDC1 KIAA1107 DGCR2 RNF126 HLTF P4HA2 CLCN4 MRPS34 NOTCH3 SLC12A1 ZNF638 RGS11 GPC4 NMRK2 UBE2T CAPN6 SIRT6 AMPH OSBPL6 AFP PALB2 PIBF1 GSTP1 ATG16L1 DIMT1 PPP1R15A TRIP6 FKBP1A ZNF343 HEPH ZBTB25 HAUS4 MFSD11 DPYSL2 CECR1 CYP26A1 NUBP2 HNRNPH3 ERMP1 PSMD8 TIMM13 EIF3L POLR2F DDX17 MCAT ABHD4 CGRRF1 SRSF5 CINP NFKBIA PSME2 C20orf24 PSMA7 GMEB2 SIRPB1 PDYN NOP56 TTI1 E2F1 LAMA1 CSTF2 PSMD10 STS GPR143 NXT2 AMMECR1 CHRDL1 SUV39H1 PLS3 MTMR8 ZC3H12B PQBP1 PCSK1N SMS CDK16 KLHL4 BEX4 INTS6 LONP2 PSMD7 HAS3 NAGPA SEC14L5 CLCN7 VPS18 STMN2 LEPROTL1 BNIP3L NFKBIB DKKL1 MED26 AKAP8 CCDC94 MRPL4 CYTH2 GRWD1 JAK3 UPK1A ARMC6 SUGP1 ATP6V0A4 C1GALT1 MRPL32 YKT6 SEC61B DNMBP FBXL15 SUFU PPIF P2RX1 INTS2 MRPL27 ELF2 VWF IL23A LTA4H TRPV4 NOP2 CHPT1 RAB35 TDP2 CE
M11 ZDHHC5 UTP14A AIFM1 RBPMS MMP14 ARMC12 KIT ERG ETS2 BRAF FMNL2 FAM213B C12orf43 PTPDC1 FAM46B TMSB15B FAM86C1 COPG2 RNF166 FGF17 NDUFS2 SLC5A11 C21orf59 CBR1 PSMB4 TCHH CCDC117 BSDC1 ATAD3B UBE2J2 NR2F6 RRP1 NACC1 ORAI2 PLXDC1 SSTR5 AMDHD2 TPCN2 PARS2 PRKAA2 GFI1 IGSF8 RBM15 BROX PPP1R21 CAPN13 HIPK1 RNF25 NUAK2 KIAA1407 CXCL1 PLSCR2 RPL39L LRPAP1 NDST3 F2RL1 KIAA1430 GRIK2 CITED2 KIAA1324L ORC5 PHAX SLC25A32 NFIL3 GKAP1 KIF27 MID1IP1 NLGN4Y ZNF488 MICU2 ARF6 SNAPC4 GFI1B SALL2 GLB1L3 IKBIP RPUSD2 TRMT61A ASPG DCHS1 SERPINB8 TUB LMO1 CRABP1 NGFRAP1 LDHC C18orf54 DCTN5 ELFN2 TRUB2 COQ4 GPRC5B ATP5L TRIM68 ZNF610 ANKRD33 DAPK3 C19orf48 TMEM68 PRR25 ZNF598 ZNF597 FADD RAB4A DDIT4 LMBRD1 COA6 PCMTD1 DTYMK POLR3D FEN1 AXIN2 TMEM208 ZBTB5 CPT1C NSMCE1 RAB3B CD2BP2 CA5B COL22A1 MMGT1 MT1E DUS1L SYAP1 ZNF764 PUSL1 SF3B5 DENND5B CDH2 COMMD5 TMEM43 TEX13B ZNF160 JAGN1 SCAND1 MRPL36 ZBTB26 POLR1C TBCA BPTF METTL18 ZNF217 THOP1 KRCC1 NME6 CYCS POP7 SUCLG2 CLP1 MANEA ZNF738 CORO1B RAB43 CBWD1 MYD88 ZNF680 MRP63 ADCY5 ZBTB21 MINOS1 THAP2 SSSCA1 LRFN4 EIF1AX GPR64 GOLIM4  ...
#         <input type="submit" value="COI">
#         </form>
# set(['IFITM2', 'TMSB4Y', 'LARGE', 'NAPRT1', 'USP9Y', 'LRRC61', 'SORBS2', 'RPS4Y1', 'CDKL5', 'PCDHB5', 'GAL', 'CITED2', 'MT1F', 'CECR1', 'PLS3', 'DDIT4', 'DDX3Y', 'ZNF680', 'HLA-DRB1', 'LEFTY1', 'HTR7', 'MT1E', 'ACOT2', 'ACOT1', 'GSTM1', 'PDK1', 'NKX1-2', 'C9orf135', 'CYP26A1', 'KDM5D', 'HES1'])

# %%
#inductiongenes_signficant_logExprData= filterPvals2GeneSymbols(origPvals.inductiongenes)
inductiongenes_signficant_logExprDataNorm= filterPvals2GeneSymbols(normPvals.inductiongenes)
nathan_inductiongenes=pd.DataFrame.from_csv('GeneCombinations-GeneExpression-signatures.csv')
matplotlib_venn.venn2([set(inductiongenes_signficant_logExprDataNorm), #set(inductiongenes_signficant_logExprData), 
                       set(nathan_inductiongenes.index)], 
                       set_labels=['normalized', 'AltAnalyze'])
pylab.title('Significant Gene counts for Induction Genes')

# %% [markdown]
# ####Explore some of the specific different genes

# %%
# Out:
# Counter({'SC': 27})

# %% [markdown]
# **Ah** This seems to be due to HESC vs iPSC - should HESC be excluded for COI analysis?
